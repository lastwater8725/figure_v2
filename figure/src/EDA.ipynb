# %%
import pandas as pd

# %% [markdown]
# ### merge된 csv파일은 이름순

# %%
cd ../
# Out:
# /mnt/c/Users/okpl8/documents/project1/figure

# %%
pwd
# Out:
# '/mnt/c/Users/okpl8/documents/project1/figure'

# %%
data = pd.read_csv('./data/merged_V2.csv')
# Out:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
columns = list(data.columns)
print(columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 columns = list(data.columns)
#       2 print(columns)
#
# AttributeError: 'TextFileReader' object has no attribute 'columns'

# %% [markdown]
# ### change csv

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(data['label'])

data["label"] = encoder.transform(data["label"])
data
# 0 = jump, 1 = spin, 2 = step
# Out:
#         image_filename       Nose_x      Nose_y       LEye_x      LEye_y  \
# 0                0.jpg  1360.591187  284.676208  1365.265259  280.002075
# 1                1.jpg  1360.383911  284.444427  1365.109741  279.718567
# 2                2.jpg  1357.580200  283.582306  1364.648682  278.870026
# 3                3.jpg  1357.493286  283.125244  1362.250610  278.367920
# 4                4.jpg  1357.119263  283.236694  1361.885376  278.470612
# ...                ...          ...         ...          ...         ...
# 1239682        152.jpg   341.348572  538.586487   341.348572  529.240417
# 1239683        153.jpg   339.694977  543.416748   339.694977  533.941956
# 1239684        154.jpg   341.479095  550.375183   341.479095  540.466553
# 1239685        155.jpg   342.858185  555.933350   342.858185  549.375977
# 1239686        156.jpg   344.824921  563.230591   344.824921  552.911072
#
#               REye_x      REye_y       LEar_x      LEar_y       REar_x  ...  \
# 0        1358.254028  280.002075  1379.287720  282.339142  1376.950684  ...
# 1        1358.020874  279.718567  1379.287354  282.081512  1376.924438  ...
# 2        1357.580200  278.870026  1378.785522  283.582306  1376.429443  ...
# 3        1357.493286  278.367920  1376.522583  283.125244  1376.522583  ...
# 4        1354.736206  278.470612  1376.183594  283.236694  1376.183594  ...
# ...              ...         ...          ...         ...          ...  ...
# 1239682   332.002502  532.355774   316.425690  538.586487   313.310333  ...
# 1239683   330.220184  537.100220   317.587097  543.416748   311.270569  ...
# 1239684   331.570465  543.769409   318.358917  547.072327   311.753143  ...
# 1239685   333.022186  552.654663   319.907501  555.933350   313.350159  ...
# 1239686   334.505402  556.350891   320.746063  559.790710   313.866394  ...
#
#          RSmallToe_x  RSmallToe_y      LHeel_x     LHeel_y      RHeel_x  \
# 0        1339.557495   478.652954  1367.602295  480.990021  1365.265259
# 1        1339.117432   480.568085  1367.472656  480.568085  1365.109741
# 2        1338.731079   479.142578  1367.004761  479.142578  1364.648682
# 3        1340.842651   478.174896  1367.007935  480.553558  1367.007935
# 4        1340.437988   476.263245  1366.651489  481.029327  1366.651489
# ...              ...          ...          ...         ...          ...
# 1239682   310.194977   806.507385   375.617523  778.469177   332.002502
# 1239683   301.795776   818.185913   374.435913  789.761536   327.061920
# 1239684   298.541595   827.817505   371.205078  794.788635   321.661804
# 1239685   293.678162   837.898804   369.087524  795.276123   316.628845
# 1239686   293.227356   852.176880   372.343628  800.579346   313.866394
#
#             RHeel_y  gender  level  label  \
# 0        476.315887       0      1      0
# 1        475.842194       0      1      0
# 2        476.786438       0      1      0
# 3        475.796234       0      1      0
# 4        476.263245       0      1      0
# ...             ...     ...    ...    ...
# 1239682  781.584534       0      3      2
# 1239683  789.761536       0      3      2
# 1239684  798.091553       0      3      2
# 1239685  808.390808       0      3      2
# 1239686  814.338684       0      3      2
#
#                                                       path
# 0        Jump/1F(Flip)/넘어짐/고급/FA01/1/camera0/video/Moti...
# 1        Jump/1F(Flip)/넘어짐/고급/FA01/1/camera0/video/Moti...
# 2        Jump/1F(Flip)/넘어짐/고급/FA01/1/camera0/video/Moti...
# 3        Jump/1F(Flip)/넘어짐/고급/FA01/1/camera0/video/Moti...
# 4        Jump/1F(Flip)/넘어짐/고급/FA01/1/camera0/video/Moti...
# ...                                                    ...
# 1239682  Step/Stroking/정상/초급/FB04/5/camera0/video/Motio...
# 1239683  Step/Stroking/정상/초급/FB04/5/camera0/video/Motio...
# 1239684  Step/Stroking/정상/초급/FB04/5/camera0/video/Motio...
# 1239685  Step/Stroking/정상/초급/FB04/5/camera0/video/Motio...
# 1239686  Step/Stroking/정상/초급/FB04/5/camera0/video/Motio...
#
# [1239687 rows x 57 columns]

# %%
data = data.drop(['image_filename','path'], axis=1)
data
# Out:
#               Nose_x      Nose_y       LEye_x      LEye_y       REye_x  \
# 0        1360.591187  284.676208  1365.265259  280.002075  1358.254028
# 1        1360.383911  284.444427  1365.109741  279.718567  1358.020874
# 2        1357.580200  283.582306  1364.648682  278.870026  1357.580200
# 3        1357.493286  283.125244  1362.250610  278.367920  1357.493286
# 4        1357.119263  283.236694  1361.885376  278.470612  1354.736206
# ...              ...         ...          ...         ...          ...
# 1239682   341.348572  538.586487   341.348572  529.240417   332.002502
# 1239683   339.694977  543.416748   339.694977  533.941956   330.220184
# 1239684   341.479095  550.375183   341.479095  540.466553   331.570465
# 1239685   342.858185  555.933350   342.858185  549.375977   333.022186
# 1239686   344.824921  563.230591   344.824921  552.911072   334.505402
#
#              REye_y       LEar_x      LEar_y       REar_x      REar_y  ...  \
# 0        280.002075  1379.287720  282.339142  1376.950684  282.339142  ...
# 1        279.718567  1379.287354  282.081512  1376.924438  282.081512  ...
# 2        278.870026  1378.785522  283.582306  1376.429443  281.226166  ...
# 3        278.367920  1376.522583  283.125244  1376.522583  283.125244  ...
# 4        278.470612  1376.183594  283.236694  1376.183594  280.853638  ...
# ...             ...          ...         ...          ...         ...  ...
# 1239682  532.355774   316.425690  538.586487   313.310333  538.586487  ...
# 1239683  537.100220   317.587097  543.416748   311.270569  546.575012  ...
# 1239684  543.769409   318.358917  547.072327   311.753143  550.375183  ...
# 1239685  552.654663   319.907501  555.933350   313.350159  555.933350  ...
# 1239686  556.350891   320.746063  559.790710   313.866394  563.230591  ...
#
#          LSmallToe_y  RSmallToe_x  RSmallToe_y      LHeel_x     LHeel_y  \
# 0         490.338318  1339.557495   478.652954  1367.602295  480.990021
# 1         490.019806  1339.117432   480.568085  1367.472656  480.568085
# 2         488.567169  1338.731079   479.142578  1367.004761  479.142578
# 3         487.689514  1340.842651   478.174896  1367.007935  480.553558
# 4         488.178467  1340.437988   476.263245  1366.651489  481.029327
# ...              ...          ...          ...          ...         ...
# 1239682   803.392029   310.194977   806.507385   375.617523  778.469177
# 1239683   811.869385   301.795776   818.185913   374.435913  789.761536
# 1239684   814.605957   298.541595   827.817505   371.205078  794.788635
# 1239685   821.505493   293.678162   837.898804   369.087524  795.276123
# 1239686   828.098022   293.227356   852.176880   372.343628  800.579346
#
#              RHeel_x     RHeel_y  gender  level  label
# 0        1365.265259  476.315887       0      1      0
# 1        1365.109741  475.842194       0      1      0
# 2        1364.648682  476.786438       0      1      0
# 3        1367.007935  475.796234       0      1      0
# 4        1366.651489  476.263245       0      1      0
# ...              ...         ...     ...    ...    ...
# 1239682   332.002502  781.584534       0      3      2
# 1239683   327.061920  789.761536       0      3      2
# 1239684   321.661804  798.091553       0      3      2
# 1239685   316.628845  808.390808       0      3      2
# 1239686   313.866394  814.338684       0      3      2
#
# [1239687 rows x 55 columns]

# %% [markdown]
# ### data visualize

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='label')
plt.title('Distribution of Actions')
plt.xlabel('Action Type (0:jump, 1:spin, 2:step)')
plt.ylabel('Count')
plt.show()

print(data.value_counts('label'))
# Out:
# label
# 0    551536
# 1    404899
# 2    283252
# Name: count, dtype: int64

# %%
from tableone import TableOne

continuous_vars = [col for col in data.columns if col != 'label']
categorical_vars = []

data['label'] = data['label'] = data['label'].map({0: 'Jump', 1: 'Spin', 2: 'Step'})

# TableOne 생성
mytable = TableOne(data, 
                  columns=continuous_vars, 
                  categorical=categorical_vars, 
                  groupby='label',
                  decimals=3)

# 결과 출력
print(mytable.tabulate(tablefmt="github"))
# Out:
# |                        |    | Missing   | Overall            | Jump               | Spin               | Step               |
# |------------------------|----|-----------|--------------------|--------------------|--------------------|--------------------|
# | n                      |    |           | 1239687            | 551536             | 404899             | 283252             |
# | Nose_x, mean (SD)      |    | 0         | 1165.888 (294.997) | 1235.679 (296.146) | 1098.287 (236.122) | 1126.626 (335.921) |
# | Nose_y, mean (SD)      |    | 0         | 398.317 (109.311)  | 394.321 (134.915)  | 407.734 (82.469)   | 392.637 (83.314)   |
# | LEye_x, mean (SD)      |    | 0         | 1166.169 (295.579) | 1236.101 (296.769) | 1097.514 (237.063) | 1128.143 (335.919) |
# | LEye_y, mean (SD)      |    | 0         | 391.909 (108.201)  | 388.132 (133.676)  | 401.152 (81.657)   | 386.050 (82.033)   |
# | REye_x, mean (SD)      |    | 0         | 1165.971 (296.281) | 1235.803 (296.889) | 1098.450 (237.227) | 1126.514 (338.450) |
# | REye_y, mean (SD)      |    | 0         | 392.144 (108.565)  | 388.325 (133.950)  | 401.446 (81.938)   | 386.281 (82.847)   |
# | LEar_x, mean (SD)      |    | 0         | 1165.819 (299.022) | 1235.065 (299.384) | 1095.309 (241.257) | 1131.779 (340.591) |
# | LEar_y, mean (SD)      |    | 0         | 393.728 (107.894)  | 389.890 (133.202)  | 403.383 (81.521)   | 387.398 (81.848)   |
# | REar_x, mean (SD)      |    | 0         | 1171.817 (301.042) | 1240.282 (299.590) | 1102.421 (242.891) | 1137.706 (346.934) |
# | REar_y, mean (SD)      |    | 0         | 393.932 (108.427)  | 390.083 (133.626)  | 403.545 (81.908)   | 387.687 (83.035)   |
# | LShoulder_x, mean (SD) |    | 0         | 1164.913 (295.629) | 1232.845 (297.047) | 1094.172 (238.627) | 1133.760 (334.937) |
# | LShoulder_y, mean (SD) |    | 0         | 428.286 (111.053)  | 423.190 (137.490)  | 438.340 (82.775)   | 423.837 (84.610)   |
# | RShoulder_x, mean (SD) |    | 0         | 1171.766 (301.009) | 1237.706 (298.123) | 1104.073 (245.074) | 1140.137 (348.742) |
# | RShoulder_y, mean (SD) |    | 0         | 427.517 (112.460)  | 422.284 (137.875)  | 438.643 (83.722)   | 421.801 (89.750)   |
# | LElbow_x, mean (SD)    |    | 0         | 1161.323 (292.571) | 1227.692 (295.857) | 1091.864 (236.560) | 1131.384 (328.375) |
# | LElbow_y, mean (SD)    |    | 0         | 468.287 (119.658)  | 462.466 (147.019)  | 475.603 (89.802)   | 469.163 (94.377)   |
# | RElbow_x, mean (SD)    |    | 0         | 1170.868 (298.930) | 1234.523 (294.579) | 1106.497 (245.264) | 1138.937 (348.284) |
# | RElbow_y, mean (SD)    |    | 0         | 465.441 (121.706)  | 459.154 (146.617)  | 476.039 (90.754)   | 462.534 (104.648)  |
# | LWrist_x, mean (SD)    |    | 0         | 1158.929 (290.796) | 1223.982 (296.143) | 1091.511 (236.843) | 1128.635 (321.699) |
# | LWrist_y, mean (SD)    |    | 0         | 494.546 (129.603)  | 489.816 (157.117)  | 495.135 (101.078)  | 502.915 (103.577)  |
# | RWrist_x, mean (SD)    |    | 0         | 1168.398 (295.965) | 1230.783 (289.910) | 1107.595 (245.271) | 1133.840 (345.929) |
# | RWrist_y, mean (SD)    |    | 0         | 489.655 (131.853)  | 484.310 (155.486)  | 495.505 (101.511)  | 491.700 (119.058)  |
# | LHip_x, mean (SD)      |    | 0         | 1163.524 (290.877) | 1225.030 (292.582) | 1096.528 (236.066) | 1139.529 (331.060) |
# | LHip_y, mean (SD)      |    | 0         | 517.223 (124.442)  | 508.973 (153.168)  | 529.804 (91.170)   | 515.304 (99.250)   |
# | RHip_x, mean (SD)      |    | 0         | 1167.176 (293.654) | 1227.535 (293.145) | 1102.206 (238.908) | 1142.520 (338.755) |
# | RHip_y, mean (SD)      |    | 0         | 517.034 (124.708)  | 508.592 (152.683)  | 530.154 (91.862)   | 514.715 (101.095)  |
# | LKnee_x, mean (SD)     |    | 0         | 1157.256 (286.197) | 1217.387 (289.705) | 1092.930 (231.463) | 1132.125 (323.870) |
# | LKnee_y, mean (SD)     |    | 0         | 572.634 (129.520)  | 559.813 (158.133)  | 587.420 (95.293)   | 576.462 (105.365)  |
# | RKnee_x, mean (SD)     |    | 0         | 1165.875 (289.379) | 1222.806 (291.010) | 1104.669 (234.557) | 1142.514 (332.782) |
# | RKnee_y, mean (SD)     |    | 0         | 571.899 (130.547)  | 559.612 (157.071)  | 586.512 (97.513)   | 574.934 (111.129)  |
# | LAnkle_x, mean (SD)    |    | 0         | 1154.836 (285.421) | 1210.809 (289.444) | 1092.835 (233.037) | 1134.476 (322.143) |
# | LAnkle_y, mean (SD)    |    | 0         | 630.705 (136.964)  | 614.238 (165.685)  | 647.086 (102.714)  | 639.351 (112.170)  |
# | RAnkle_x, mean (SD)    |    | 0         | 1164.324 (289.749) | 1216.640 (292.364) | 1104.854 (235.998) | 1147.465 (332.743) |
# | RAnkle_y, mean (SD)    |    | 0         | 628.236 (140.549)  | 613.690 (166.224)  | 644.209 (106.269)  | 633.727 (125.318)  |
# | Head_x, mean (SD)      |    | 0         | 1167.991 (300.142) | 1237.951 (300.054) | 1098.351 (241.897) | 1131.316 (342.799) |
# | Head_y, mean (SD)      |    | 0         | 367.921 (103.816)  | 365.069 (128.297)  | 376.639 (78.547)   | 361.014 (78.285)   |
# | Neck_x, mean (SD)      |    | 0         | 1168.794 (298.630) | 1236.678 (298.044) | 1099.245 (241.327) | 1136.034 (342.244) |
# | Neck_y, mean (SD)      |    | 0         | 411.392 (109.644)  | 406.900 (135.165)  | 421.585 (82.296)   | 405.570 (84.487)   |
# | Hip_x, mean (SD)       |    | 0         | 1165.416 (292.399) | 1226.563 (292.902) | 1099.265 (237.547) | 1140.915 (335.173) |
# | Hip_y, mean (SD)       |    | 0         | 513.814 (123.902)  | 505.607 (152.109)  | 526.399 (91.150)   | 511.804 (99.495)   |
# | LBigToe_x, mean (SD)   |    | 0         | 1149.338 (282.380) | 1205.437 (287.851) | 1089.813 (228.836) | 1125.192 (317.830) |
# | LBigToe_y, mean (SD)   |    | 0         | 643.391 (138.075)  | 626.440 (166.958)  | 660.510 (102.670)  | 651.927 (114.203)  |
# | RBigToe_x, mean (SD)   |    | 0         | 1162.466 (286.715) | 1213.609 (290.333) | 1106.173 (232.905) | 1143.349 (328.819) |
# | RBigToe_y, mean (SD)   |    | 0         | 640.393 (141.147)  | 625.728 (166.903)  | 656.423 (106.738)  | 646.035 (125.888)  |
# | LSmallToe_x, mean (SD) |    | 0         | 1150.159 (282.568) | 1206.335 (288.354) | 1089.950 (229.437) | 1126.842 (316.905) |
# | LSmallToe_y, mean (SD) |    | 0         | 643.996 (137.599)  | 626.895 (166.441)  | 660.776 (103.045)  | 653.308 (112.635)  |
# | RSmallToe_x, mean (SD) |    | 0         | 1162.594 (288.035) | 1213.610 (291.047) | 1106.138 (234.157) | 1143.961 (331.384) |
# | RSmallToe_y, mean (SD) |    | 0         | 640.155 (142.272)  | 625.338 (167.956)  | 656.725 (107.326)  | 645.321 (127.861)  |
# | LHeel_x, mean (SD)     |    | 0         | 1155.283 (286.415) | 1210.432 (290.089) | 1093.152 (234.853) | 1136.715 (323.334) |
# | LHeel_y, mean (SD)     |    | 0         | 640.314 (138.215)  | 623.034 (166.757)  | 657.026 (104.399)  | 650.074 (113.166)  |
# | RHeel_x, mean (SD)     |    | 0         | 1165.076 (290.970) | 1216.747 (293.739) | 1105.157 (237.507) | 1150.118 (333.685) |
# | RHeel_y, mean (SD)     |    | 0         | 637.126 (142.112)  | 622.268 (167.573)  | 653.165 (107.882)  | 643.130 (127.444)  |
# | gender, mean (SD)      |    | 0         | 0.206 (0.405)      | 0.193 (0.394)      | 0.211 (0.408)      | 0.227 (0.419)      |
# | level, mean (SD)       |    | 0         | 2.143 (0.799)      | 2.071 (0.812)      | 2.182 (0.788)      | 2.226 (0.778)      |

# %% [markdown]
# ### 그룹간 차이 분석

# %%
import scipy.stats as stats
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Scientific notation setting
pd.set_option('display.float_format', lambda x: '%.2e' % x if abs(x) < 0.01 else '%.4f' % x)

features = [col for col in data.columns if col != 'label']
analysis_results = []

for feature in features:
    jump_data = data[data['label'] == 'Jump'][feature]
    spin_data = data[data['label'] == 'Spin'][feature]
    step_data = data[data['label'] == 'Step'][feature]
    
    f_stat, p_val = f_oneway(jump_data, spin_data, step_data)
    
    groups = [jump_data, spin_data, step_data]
    ss_between = sum(len(group) * ((group.mean() - data[feature].mean())**2) for group in groups)
    ss_total = sum((data[feature] - data[feature].mean())**2)
    eta_squared = ss_between / ss_total
    
    if eta_squared < 0.01:
        effect_size_interpretation = "Small Effect"
    elif eta_squared < 0.06:
        effect_size_interpretation = "Medium Effect"
    else:
        effect_size_interpretation = "Large Effect"
    
    desc_stats = data.groupby('label')[feature].agg(['mean', 'std']).round(4)
    
    analysis_results.append({
        'Feature': feature,
        'F-statistic': f_stat,
        'p-value': p_val,
        'Effect Size (η²)': eta_squared,
        'Effect Interpretation': effect_size_interpretation,
        'Jump_mean': desc_stats.loc['Jump', 'mean'],
        'Jump_std': desc_stats.loc['Jump', 'std'],
        'Spin_mean': desc_stats.loc['Spin', 'mean'],
        'Spin_std': desc_stats.loc['Spin', 'std'],
        'Step_mean': desc_stats.loc['Step', 'mean'],
        'Step_std': desc_stats.loc['Step', 'std']
    })

results_df = pd.DataFrame(analysis_results)
results_df = results_df.sort_values('Effect Size (η²)', ascending=False)

print("\n=== Overall Variable Analysis Results ===")
print(results_df)
# Out:
# === Overall Variable Analysis Results ===
#         Feature  F-statistic   p-value  Effect Size (η²)  \
# 2        LEye_x   30096.5552  0.00e+00            0.0463
# 0        Nose_x   29955.6940  0.00e+00            0.0461
# 4        REye_x   29704.0062  0.00e+00            0.0457
# 34       Head_x   29320.3450  0.00e+00            0.0452
# 6        LEar_x   29193.6560  0.00e+00            0.0450
# 10  LShoulder_x   29024.3668  0.00e+00            0.0447
# 14     LElbow_x   28321.8827  0.00e+00            0.0437
# 36       Neck_x   28158.4315  0.00e+00            0.0435
# 8        REar_x   28054.6197  0.00e+00            0.0433
# 18     LWrist_x   27377.4395  0.00e+00            0.0423
# 12  RShoulder_x   26089.6416  0.00e+00            0.0404
# 22       LHip_x   25002.6835  0.00e+00            0.0388
# 16     RElbow_x   24435.2445  0.00e+00            0.0379
# 26      LKnee_x   24418.0646  0.00e+00            0.0379
# 38        Hip_x   24335.1705  0.00e+00            0.0378
# 20     RWrist_x   23592.8952  0.00e+00            0.0367
# 24       RHip_x   23411.2230  0.00e+00            0.0364
# 44  LSmallToe_x   21795.7287  0.00e+00            0.0340
# 40    LBigToe_x   21645.6689  0.00e+00            0.0337
# 30     LAnkle_x   21607.0841  0.00e+00            0.0337
# 28      RKnee_x   21365.0465  0.00e+00            0.0333
# 48      LHeel_x   21036.8656  0.00e+00            0.0328
# 32     RAnkle_x   18535.9906  0.00e+00            0.0290
# 50      RHeel_x   18173.3460  0.00e+00            0.0285
# 42    RBigToe_x   17699.4130  0.00e+00            0.0278
# 46  RSmallToe_x   17501.6582  0.00e+00            0.0275
# 49      LHeel_y    8080.6577  0.00e+00            0.0129
# 45  LSmallToe_y    8021.2642  0.00e+00            0.0128
# 41    LBigToe_y    7909.2273  0.00e+00            0.0126
# 31     LAnkle_y    7536.9719  0.00e+00            0.0120
# 47  RSmallToe_y    5981.0569  0.00e+00          9.56e-03
# 51      RHeel_y    5901.3685  0.00e+00          9.43e-03
# 43    RBigToe_y    5869.3789  0.00e+00          9.38e-03
# 33     RAnkle_y    5839.1934  0.00e+00          9.33e-03
# 27      LKnee_y    5512.9952  0.00e+00          8.82e-03
# 29      RKnee_y    5097.5376  0.00e+00          8.16e-03
# 53        level    4253.4004  0.00e+00          6.82e-03
# 25       RHip_y    3573.8269  0.00e+00          5.73e-03
# 39        Hip_y    3353.8324  0.00e+00          5.38e-03
# 23       LHip_y    3332.6826  0.00e+00          5.35e-03
# 13  RShoulder_y    2958.4534  0.00e+00          4.75e-03
# 37       Neck_y    2623.1129  0.00e+00          4.21e-03
# 11  LShoulder_y    2477.3107  0.00e+00          3.98e-03
# 7        LEar_y    2467.4336  0.00e+00          3.96e-03
# 9        REar_y    2418.0319  0.00e+00          3.89e-03
# 17     RElbow_y    2360.9272  0.00e+00          3.79e-03
# 35       Head_y    2271.0921  0.00e+00          3.65e-03
# 1        Nose_y    2261.4781  0.00e+00          3.64e-03
# 5        REye_y    2248.4945  0.00e+00          3.61e-03
# 3        LEye_y    2236.5543  0.00e+00          3.60e-03
# 15     LElbow_y    1420.2263  0.00e+00          2.29e-03
# 19     LWrist_y     963.4493  0.00e+00          1.55e-03
# 21     RWrist_y     887.0969  0.00e+00          1.43e-03
# 52       gender     711.7910 1.12e-309          1.15e-03
#
#    Effect Interpretation  Jump_mean  Jump_std  Spin_mean  Spin_std  Step_mean  \
# 2          Medium Effect  1236.1010  296.7686  1097.5139  237.0632  1128.1425
# 0          Medium Effect  1235.6785  296.1455  1098.2872  236.1223  1126.6258
# 4          Medium Effect  1235.8032  296.8886  1098.4504  237.2271  1126.5144
# 34         Medium Effect  1237.9510  300.0539  1098.3511  241.8969  1131.3161
# 6          Medium Effect  1235.0649  299.3838  1095.3094  241.2570  1131.7792
# 10         Medium Effect  1232.8446  297.0469  1094.1717  238.6272  1133.7597
# 14         Medium Effect  1227.6916  295.8570  1091.8640  236.5597  1131.3843
# 36         Medium Effect  1236.6777  298.0439  1099.2447  241.3272  1136.0343
# 8          Medium Effect  1240.2818  299.5904  1102.4212  242.8906  1137.7056
# 18         Medium Effect  1223.9821  296.1432  1091.5109  236.8433  1128.6346
# 12         Medium Effect  1237.7057  298.1231  1104.0731  245.0737  1140.1375
# 22         Medium Effect  1225.0296  292.5820  1096.5281  236.0658  1139.5291
# 16         Medium Effect  1234.5234  294.5790  1106.4966  245.2636  1138.9374
# 26         Medium Effect  1217.3871  289.7047  1092.9300  231.4630  1132.1253
# 38         Medium Effect  1226.5626  292.9025  1099.2652  237.5465  1140.9151
# 20         Medium Effect  1230.7826  289.9096  1107.5946  245.2708  1133.8403
# 24         Medium Effect  1227.5353  293.1451  1102.2065  238.9084  1142.5198
# 44         Medium Effect  1206.3353  288.3538  1089.9503  229.4369  1126.8423
# 40         Medium Effect  1205.4369  287.8506  1089.8133  228.8365  1125.1924
# 30         Medium Effect  1210.8092  289.4437  1092.8349  233.0366  1134.4756
# 28         Medium Effect  1222.8061  291.0099  1104.6692  234.5573  1142.5143
# 48         Medium Effect  1210.4323  290.0890  1093.1516  234.8532  1136.7149
# 32         Medium Effect  1216.6396  292.3640  1104.8545  235.9978  1147.4652
# 50         Medium Effect  1216.7469  293.7386  1105.1574  237.5067  1150.1185
# 42         Medium Effect  1213.6091  290.3328  1106.1733  232.9050  1143.3488
# 46         Medium Effect  1213.6096  291.0474  1106.1381  234.1574  1143.9606
# 49         Medium Effect   623.0336  166.7567   657.0260  104.3991   650.0743
# 45         Medium Effect   626.8949  166.4414   660.7760  103.0451   653.3080
# 41         Medium Effect   626.4403  166.9577   660.5103  102.6704   651.9271
# 31         Medium Effect   614.2384  165.6848   647.0864  102.7141   639.3511
# 47          Small Effect   625.3383  167.9555   656.7253  107.3255   645.3207
# 51          Small Effect   622.2684  167.5734   653.1649  107.8818   643.1300
# 43          Small Effect   625.7282  166.9033   656.4229  106.7382   646.0352
# 33          Small Effect   613.6898  166.2239   644.2086  106.2694   633.7269
# 27          Small Effect   559.8132  158.1328   587.4205   95.2933   576.4624
# 29          Small Effect   559.6121  157.0707   586.5119   97.5129   574.9336
# 53          Small Effect     2.0713    0.8123     2.1822    0.7883     2.2258
# 25          Small Effect   508.5923  152.6834   530.1541   91.8625   514.7152
# 39          Small Effect   505.6071  152.1092   526.3990   91.1497   511.8043
# 23          Small Effect   508.9730  153.1683   529.8037   91.1705   515.3043
# 13          Small Effect   422.2843  137.8753   438.6430   83.7216   421.8012
# 37          Small Effect   406.8997  135.1650   421.5853   82.2963   405.5696
# 11          Small Effect   423.1900  137.4903   438.3403   82.7753   423.8368
# 7           Small Effect   389.8901  133.2023   403.3831   81.5210   387.3976
# 9           Small Effect   390.0825  133.6265   403.5448   81.9076   387.6872
# 17          Small Effect   459.1536  146.6175   476.0394   90.7537   462.5344
# 35          Small Effect   365.0691  128.2966   376.6393   78.5465   361.0137
# 1           Small Effect   394.3209  134.9154   407.7335   82.4693   392.6372
# 5           Small Effect   388.3253  133.9503   401.4458   81.9378   386.2814
# 3           Small Effect   388.1315  133.6758   401.1515   81.6569   386.0503
# 15          Small Effect   462.4657  147.0191   475.6027   89.8021   469.1626
# 19          Small Effect   489.8163  157.1172   495.1347  101.0777   502.9147
# 21          Small Effect   484.3098  155.4865   495.5053  101.5114   491.6997
# 52          Small Effect     0.1925    0.3943     0.2113    0.4082     0.2268
#
#     Step_std
# 2   335.9193
# 0   335.9212
# 4   338.4503
# 34  342.7992
# 6   340.5912
# 10  334.9373
# 14  328.3755
# 36  342.2440
# 8   346.9344
# 18  321.6989
# 12  348.7423
# 22  331.0603
# 16  348.2837
# 26  323.8701
# 38  335.1732
# 20  345.9289
# 24  338.7553
# 44  316.9048
# 40  317.8304
# 30  322.1431
# 28  332.7822
# 48  323.3339
# 32  332.7434
# 50  333.6850
# 42  328.8186
# 46  331.3839
# 49  113.1656
# 45  112.6352
# 41  114.2032
# 31  112.1704
# 47  127.8613
# 51  127.4438
# 43  125.8884
# 33  125.3183
# 27  105.3651
# 29  111.1289
# 53    0.7779
# 25  101.0951
# 39   99.4947
# 23   99.2502
# 13   89.7499
# 37   84.4869
# 11   84.6103
# 7    81.8477
# 9    83.0348
# 17  104.6477
# 35   78.2846
# 1    83.3138
# 5    82.8470
# 3    82.0328
# 15   94.3775
# 19  103.5772
# 21  119.0583
# 52    0.4187

# %% [markdown]
# ### 전체 effect 분포
#
# - 54개 변수 중 52개가 중간 이상의 효과 -> 대부분이 동작 구분에 유의미
# - 상위 변수는 x축 움직임(좌우)
# - 상체 변수들이 많으므로, 상체 부위가 주요하고 동작마다 상체의 자세가 다름.
# - p-value가 0에 가까움으로 실제차이로 볼수있음
# - gender는 동작 구분에서 관련이 적음

# %%
# 동작별 상위 10개의 박스플롯

top_10_features = results_df.head(10)['Feature'].tolist()

plt.figure(figsize=(15, 20))
for idx, feature in enumerate(top_10_features, 1):
    plt.subplot(5, 2, idx)
    sns.boxplot(x='label', y=feature, data=data)
    result_row = results_df[results_df['Feature']==feature].iloc[0]
    plt.title(f'{feature}\nη² = {result_row["Effect Size (η²)"]:.4f}\n{result_row["Effect Interpretation"]}')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
plt.hist(results_df['Effect Size (η²)'], bins=30)
plt.axvline(x=0.01, color='r', linestyle='--', label='Small Effect Threshold')
plt.axvline(x=0.06, color='g', linestyle='--', label='Medium Effect Threshold')
plt.axvline(x=0.14, color='b', linestyle='--', label='Large Effect Threshold')
plt.title('Distribution of Effect Sizes (η²)')
plt.xlabel('Effect Size (η²)')
plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# ### insight
# - 상위 특성들이 동작별로 뚜렷한 차이, jump가 높은 x spin이 가장 낮음, 동작내에 여러 변동성
# - η² = SS(between) / SS(total)
#    = 그룹간 제곱합 / 전체 제곱합
#    전체 변동(variation) 중에서 그룹 차이로 설명되는 비율
# 쉽게 말해 "이 변수가 그룹을 얼마나 잘 구분하는지"를 0~1 사이의 값으로 나타냄
# 의미: 왼쪽 어깨의 x좌표 변동의 8.14%가
#      Jump/Spin/Step 동작의 차이로 설명됨
#      η² < 0.01: 작은 효과 (1% 미만 설명)
# η² ≥ 0.01: 중간 효과 (1% 이상 설명)
# η² ≥ 0.06: 큰 효과 (6% 이상 설명)

# %%
effect_size_summary = results_df['Effect Interpretation'].value_counts()
print("\n=== Effect Size Classification Summary ===")
print(effect_size_summary)

print("\n=== Top 20 Variables by Effect Size ===")
top_20 = results_df[['Feature', 'Effect Size (η²)', 'p-value', 'Effect Interpretation']].head(20)
print(top_20)

results_df['max_mean_diff'] = results_df.apply(lambda row: max([
    abs(row['Jump_mean'] - row['Spin_mean']),
    abs(row['Jump_mean'] - row['Step_mean']),
    abs(row['Spin_mean'] - row['Step_mean'])
]), axis=1)

print("\n=== Top 20 Variables by Mean Difference Between Groups ===")
mean_diff_top20 = results_df.sort_values('max_mean_diff', ascending=False)[
    ['Feature', 'max_mean_diff', 'Effect Size (η²)', 'Effect Interpretation', 'p-value']
].head(20)
print(mean_diff_top20)

results_df.to_csv('group_difference_analysis_results.csv', index=False)
# Out:
# === Effect Size Classification Summary ===
# Effect Interpretation
# Medium Effect    30
# Small Effect     24
# Name: count, dtype: int64
#
# === Top 20 Variables by Effect Size ===
#         Feature  Effect Size (η²)  p-value Effect Interpretation
# 2        LEye_x            0.0463 0.00e+00         Medium Effect
# 0        Nose_x            0.0461 0.00e+00         Medium Effect
# 4        REye_x            0.0457 0.00e+00         Medium Effect
# 34       Head_x            0.0452 0.00e+00         Medium Effect
# 6        LEar_x            0.0450 0.00e+00         Medium Effect
# 10  LShoulder_x            0.0447 0.00e+00         Medium Effect
# 14     LElbow_x            0.0437 0.00e+00         Medium Effect
# 36       Neck_x            0.0435 0.00e+00         Medium Effect
# 8        REar_x            0.0433 0.00e+00         Medium Effect
# 18     LWrist_x            0.0423 0.00e+00         Medium Effect
# 12  RShoulder_x            0.0404 0.00e+00         Medium Effect
# 22       LHip_x            0.0388 0.00e+00         Medium Effect
# 16     RElbow_x            0.0379 0.00e+00         Medium Effect
# 26      LKnee_x            0.0379 0.00e+00         Medium Effect
# 38        Hip_x            0.0378 0.00e+00         Medium Effect
# 20     RWrist_x            0.0367 0.00e+00         Medium Effect
# 24       RHip_x            0.0364 0.00e+00         Medium Effect
# 44  LSmallToe_x            0.0340 0.00e+00         Medium Effect
# 40    LBigToe_x            0.0337 0.00e+00         Medium Effect
# 30     LAnkle_x            0.0337 0.00e+00         Medium Effect
#
# === Top 20 Variables by Mean Difference Between Groups ===
#         Feature  max_mean_diff  Effect Size (η²) Effect Interpretation  \
# 6        LEar_x       139.7555            0.0450         Medium Effect
# 34       Head_x       139.5999            0.0452         Medium Effect
# 10  LShoulder_x       138.6729            0.0447         Medium Effect
# 2        LEye_x       138.5871            0.0463         Medium Effect
# 8        REar_x       137.8606            0.0433         Medium Effect
# 36       Neck_x       137.4330            0.0435         Medium Effect
# 0        Nose_x       137.3913            0.0461         Medium Effect
# 4        REye_x       137.3528            0.0457         Medium Effect
# 14     LElbow_x       135.8276            0.0437         Medium Effect
# 12  RShoulder_x       133.6326            0.0404         Medium Effect
# 18     LWrist_x       132.4712            0.0423         Medium Effect
# 22       LHip_x       128.5015            0.0388         Medium Effect
# 16     RElbow_x       128.0268            0.0379         Medium Effect
# 38        Hip_x       127.2974            0.0378         Medium Effect
# 24       RHip_x       125.3288            0.0364         Medium Effect
# 26      LKnee_x       124.4571            0.0379         Medium Effect
# 20     RWrist_x       123.1880            0.0367         Medium Effect
# 28      RKnee_x       118.1369            0.0333         Medium Effect
# 30     LAnkle_x       117.9743            0.0337         Medium Effect
# 48      LHeel_x       117.2807            0.0328         Medium Effect
#
#     p-value
# 6  0.00e+00
# 34 0.00e+00
# 10 0.00e+00
# 2  0.00e+00
# 8  0.00e+00
# 36 0.00e+00
# 0  0.00e+00
# 4  0.00e+00
# 14 0.00e+00
# 12 0.00e+00
# 18 0.00e+00
# 22 0.00e+00
# 16 0.00e+00
# 38 0.00e+00
# 24 0.00e+00
# 26 0.00e+00
# 20 0.00e+00
# 28 0.00e+00
# 30 0.00e+00
# 48 0.00e+00

# %% [markdown]
# ##

# %% [markdown]
# ### 결론
# - 54개 중 42개가 중간의상의 효과
# - x축이며 상체, p-value가 매우 작으므로 통계적으로 유의미
# - 상위 5개:
# 1. LEar_x: 194.28 픽셀 차이
# 2. Head_x: 193.79 픽셀 차이
# 3. LShoulder_x: 193.62 픽셀 차이
# 4. REar_x: 192.99 픽셀 차이
# 5. Neck_x: 192.37 픽셀 차이
# - 동작간 차이가 194픽셀까지 나는데 동작구분이 명확할수있음을 시사
# - 왼쪽이 오른쪽 보다 더 큰 효과를 보이며, 카메라 기준 왼쪽으로 돌아서 그럴수도
#
# 1. 상체의 좌우 움직임에 집중해야 함
# 2. 특히 왼쪽 신체 부위의 움직임이 중요
# 3. 머리, 어깨, 귀 부위의 추적이 핵심적

# %% [markdown]
# ### 추가
# x좌표 (좌우):
# - 왼쪽에서 오른쪽으로 갈수록 값이 증가
# - 예: LShoulder_x의 경우
#   Jump: 1264.71 픽셀 (더 오른쪽)
#   Spin: 1071.09 픽셀 (더 왼쪽)
#   Step: 1125.34 픽셀 (중간)
#
# y좌표 (상하):
# - 위에서 아래로 갈수록 값이 증가

# %%
data.head()
# Out:
#      Nose_x   Nose_y    LEye_x   LEye_y    REye_x   REye_y    LEar_x   LEar_y  \
# 0 1360.5912 284.6762 1365.2653 280.0021 1358.2540 280.0021 1379.2877 282.3391
# 1 1360.3839 284.4444 1365.1097 279.7186 1358.0209 279.7186 1379.2874 282.0815
# 2 1357.5802 283.5823 1364.6487 278.8700 1357.5802 278.8700 1378.7855 283.5823
# 3 1357.4933 283.1252 1362.2506 278.3679 1357.4933 278.3679 1376.5226 283.1252
# 4 1357.1193 283.2367 1361.8854 278.4706 1354.7362 278.4706 1376.1836 283.2367
#
#      REar_x   REar_y  ...  LSmallToe_y  RSmallToe_x  RSmallToe_y   LHeel_x  \
# 0 1376.9507 282.3391  ...     490.3383    1339.5575     478.6530 1367.6023
# 1 1376.9244 282.0815  ...     490.0198    1339.1174     480.5681 1367.4727
# 2 1376.4294 281.2262  ...     488.5672    1338.7311     479.1426 1367.0048
# 3 1376.5226 283.1252  ...     487.6895    1340.8427     478.1749 1367.0079
# 4 1376.1836 280.8536  ...     488.1785    1340.4380     476.2632 1366.6515
#
#    LHeel_y   RHeel_x  RHeel_y  gender  level  label
# 0 480.9900 1365.2653 476.3159       0      1   Jump
# 1 480.5681 1365.1097 475.8422       0      1   Jump
# 2 479.1426 1364.6487 476.7864       0      1   Jump
# 3 480.5536 1367.0079 475.7962       0      1   Jump
# 4 481.0293 1366.6515 476.2632       0      1   Jump
#
# [5 rows x 55 columns]

# %% [markdown]
# ## heatmap

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(data['label'])

data["label"] = encoder.transform(data["label"])
data
# 0 = jump, 1 = spin, 2 = step
# Out:
#            Nose_x   Nose_y    LEye_x   LEye_y    REye_x   REye_y    LEar_x  \
# 0       1360.5912 284.6762 1365.2653 280.0021 1358.2540 280.0021 1379.2877
# 1       1360.3839 284.4444 1365.1097 279.7186 1358.0209 279.7186 1379.2874
# 2       1357.5802 283.5823 1364.6487 278.8700 1357.5802 278.8700 1378.7855
# 3       1357.4933 283.1252 1362.2506 278.3679 1357.4933 278.3679 1376.5226
# 4       1357.1193 283.2367 1361.8854 278.4706 1354.7362 278.4706 1376.1836
# ...           ...      ...       ...      ...       ...      ...       ...
# 1239682  341.3486 538.5865  341.3486 529.2404  332.0025 532.3558  316.4257
# 1239683  339.6950 543.4167  339.6950 533.9420  330.2202 537.1002  317.5871
# 1239684  341.4791 550.3752  341.4791 540.4666  331.5705 543.7694  318.3589
# 1239685  342.8582 555.9333  342.8582 549.3760  333.0222 552.6547  319.9075
# 1239686  344.8249 563.2306  344.8249 552.9111  334.5054 556.3509  320.7461
#
#           LEar_y    REar_x   REar_y  ...  LSmallToe_y  RSmallToe_x  \
# 0       282.3391 1376.9507 282.3391  ...     490.3383    1339.5575
# 1       282.0815 1376.9244 282.0815  ...     490.0198    1339.1174
# 2       283.5823 1376.4294 281.2262  ...     488.5672    1338.7311
# 3       283.1252 1376.5226 283.1252  ...     487.6895    1340.8427
# 4       283.2367 1376.1836 280.8536  ...     488.1785    1340.4380
# ...          ...       ...      ...  ...          ...          ...
# 1239682 538.5865  313.3103 538.5865  ...     803.3920     310.1950
# 1239683 543.4167  311.2706 546.5750  ...     811.8694     301.7958
# 1239684 547.0723  311.7531 550.3752  ...     814.6060     298.5416
# 1239685 555.9333  313.3502 555.9333  ...     821.5055     293.6782
# 1239686 559.7907  313.8664 563.2306  ...     828.0980     293.2274
#
#          RSmallToe_y   LHeel_x  LHeel_y   RHeel_x  RHeel_y  gender  level  \
# 0           478.6530 1367.6023 480.9900 1365.2653 476.3159       0      1
# 1           480.5681 1367.4727 480.5681 1365.1097 475.8422       0      1
# 2           479.1426 1367.0048 479.1426 1364.6487 476.7864       0      1
# 3           478.1749 1367.0079 480.5536 1367.0079 475.7962       0      1
# 4           476.2632 1366.6515 481.0293 1366.6515 476.2632       0      1
# ...              ...       ...      ...       ...      ...     ...    ...
# 1239682     806.5074  375.6175 778.4692  332.0025 781.5845       0      3
# 1239683     818.1859  374.4359 789.7615  327.0619 789.7615       0      3
# 1239684     827.8175  371.2051 794.7886  321.6618 798.0916       0      3
# 1239685     837.8988  369.0875 795.2761  316.6288 808.3908       0      3
# 1239686     852.1769  372.3436 800.5793  313.8664 814.3387       0      3
#
#          label
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 1239682      2
# 1239683      2
# 1239684      2
# 1239685      2
# 1239686      2
#
# [1239687 rows x 55 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(20, 16))
correlation = data.corr()
sns.heatmap(correlation,
            cmap='coolwarm',
            center=0,
            annot=True,
            fmt='.2f')
plt.title('corr heatmap')
plt.show()

# %% [markdown]
# ### 해석
# - x좌표들간 강한 양의 상관관계
# - y좌표들간 강한 양의 상관관계
# - x,y의 관계는 약한 상관관계

# %%
# 주요 특성 히트맵
top_20_features = results_df.head(20)['Feature'].tolist()
plt.figure(figsize=(15, 12))
correlation_top20 = data[top_20_features].corr()
sns.heatmap(correlation_top20,
            cmap='coolwarm',
            center=0,
            annot=True,      # 상위 20개만 보므로 값을 표시
            fmt='.2f')
plt.title('Correlation Heatmap of Top 20 Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 상위 20개 특성 해석
# - 대부분 x좌표
# |- 강함
# - 특정 상체 부위가 매우 강함 (붙어있는 것)_

# %%
# 3. 각 동작별 평균값의 히트맵
# x, y 좌표를 구분하여 시각화
features_x = [f for f in data.columns if f.endswith('_x') and f != 'label']
features_y = [f for f in data.columns if f.endswith('_y') and f != 'label']

# X 좌표에 대한 히트맵
mean_by_label_x = data.groupby('label')[features_x].mean()
plt.figure(figsize=(15, 5))
sns.heatmap(mean_by_label_x,
            cmap='coolwarm',
            center=mean_by_label_x.mean().mean(),
            annot=True,
            fmt='.1f')
plt.title('Mean X-coordinates by Movement Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 동작별 평균 값
# - x좌표에서 jump는 높음(오른쪽에 위치), spin은 낮음(왼쪽 값), step은 중간
# - y좌표에서는 jump는 낮은 값(위), spin은 높음(아래)

# %%
# Y 좌표에 대한 히트맵
mean_by_label_y = data.groupby('label')[features_y].mean()
plt.figure(figsize=(15, 5))
sns.heatmap(mean_by_label_y,
            cmap='coolwarm',
            center=mean_by_label_y.mean().mean(),
            annot=True,
            fmt='.1f')
plt.title('Mean Y-coordinates by Movement Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### effect size
# - x보다 y가 효과가 더 적음

# %%
# 4. Effect Size 히트맵
# x, y 좌표별로 effect size를 시각화
effect_sizes = results_df[['Feature', 'Effect Size (η²)']]
effect_sizes_matrix = pd.DataFrame(index=['x', 'y'])

# 각 신체 부위별로 x, y 좌표의 effect size를 매트릭스로 변환
for feature in effect_sizes['Feature']:
    if feature not in ['level', 'gender']:
        body_part = feature.rsplit('_', 1)[0]
        coord = feature.rsplit('_', 1)[1]
        effect_size = effect_sizes[effect_sizes['Feature'] == feature]['Effect Size (η²)'].values[0]
        effect_sizes_matrix.loc[coord, body_part] = effect_size

plt.figure(figsize=(15, 5))
sns.heatmap(effect_sizes_matrix,
            cmap='YlOrRd',
            annot=True,
            fmt='.3f')
plt.title('Effect Sizes (η²) by Body Part and Coordinate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## pearson 상관관계 히트맵

# %%
# 전체 상관관계 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 16))
correlation = data.corr(method='pearson')

sns.heatmap(correlation,
            cmap='coolwarm',
            center=0,
            annot=True,
            fmt='.2f',
            square=True,
            vmin=-1,
            vmax=1)

plt.title('pearson Correlataion Map of All')
plt.show()

# %% [markdown]
# ### all
# - x,y끼리 군집
# - gender, lebel은 약함
# - 상체의 x가 강한 상관관계
# - 하체로 갈수록 약해짐

# %%
# 상위 20개 특성 corr
top_20 = results_df.head(20)['Feature'].tolist()
plt.figure(figsize=(15,12))
correlation_20 = data[top_20].corr(method='pearson')

sns.heatmap(correlation_20,
            cmap='coolwarm',
            annot=True,
            fmt='.2f',
            square=True,
            vmin=-1,
            vmax=1)
plt.title('pearson corr top 20')
plt.show()

# %% [markdown]
# ### 20
# - 대부분 x.좌표이며 높은 상관계수임 0.8, 1.0
# - 머리 어깨 팔의 위치가 같으면 높음

# %%
# 상관관계 hist
plt.figure(figsize=(12,6))
corr_value = correlation.values.flatten()
plt.hist(corr_value, bins=50)
plt.title('Distribution of Correlation Coefficients')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 상관관계 히스트
# - 매우 강한 양의 상관관계를 가진 변수가 많음
# - 음의 상관관계는 반대로 움직이는 관계를 나타냄
# - 많은 신체 부위가 같은 방향으로 움직이고, 상체부위가 많음

# %% [markdown]
# ### 모든 변수가 동일한 단위에 있으므로 스케일링은 따로 진행하지 않음
