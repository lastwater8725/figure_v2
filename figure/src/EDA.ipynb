# %%
import pandas as pd

# %% [markdown]
# ### merge된 csv파일은 이름순

# %%
cd ../
# Out:
# c:\Users\okpl8\Documents\project1\figure

# %%
pwd
# Out:
# 'c:\\Users\\okpl8\\Documents\\project1\\figure'

# %%
data = pd.read_csv('./data/merged.csv')
data.head(-5)
# Out:
#        image_filename       Nose_x      Nose_y       LEye_x      LEye_y  \
# 0              65.jpg  1903.450439  324.195709  1896.498169  317.243469
# 1              66.jpg  1902.256348  330.161255  1902.256348  325.993469
# 2              67.jpg  1899.319946  328.725464  1917.416260  300.575562
# 3              68.jpg  1914.982666  298.280396  1916.995972  296.267059
# 4              69.jpg  1914.923340  295.087738  1910.812134  295.087738
# ...               ...          ...         ...          ...         ...
# 531730        156.jpg  1586.169922  489.820007  1535.429321  485.207214
# 531731        157.jpg  1591.809814  491.560486  1547.398926  482.678314
# 531732        158.jpg  1597.948608  485.454712  1558.098755  476.599213
# 531733        159.jpg  1566.711426  477.108459  1566.711426  468.333588
# 531734        160.jpg  1576.791138  474.224396  1576.791138  465.091980
#
#              REye_x      REye_y       LEar_x      LEar_y       REar_x  ...  \
# 0       1896.498169  317.243469  1908.085205  326.513123  1908.085205  ...
# 1       1908.508057  332.245117  1906.424072  328.077362  1916.843506  ...
# 2       1917.416260  298.564880  1901.330566  328.725464  1920.000000  ...
# 3       1914.982666  296.267059  1916.995972  296.267059  1920.000000  ...
# 4       1912.867676  295.087738  1914.923340  293.032135  1920.000000  ...
# ...             ...         ...          ...         ...          ...  ...
# 531730  1581.557129  485.207214  1535.429321  485.207214  1586.169922  ...
# 531731  1591.809814  478.237244  1547.398926  478.237244  1596.250854  ...
# 531732  1602.376343  476.599213  1558.098755  476.599213  1606.804199  ...
# 531733  1614.973267  468.333588  1566.711426  468.333588  1614.973267  ...
# 531734  1617.887085  465.091980  1576.791138  465.091980  1622.453247  ...
#
#         LSmallToe_y  RSmallToe_x  RSmallToe_y      LHeel_x     LHeel_y  \
# 0        433.114258  1877.958862   426.162018  1903.450439  435.431671
# 1        431.238159  1873.883179   425.009338  1902.474854  432.223877
# 2        430.018127  1871.919434   423.960632  1898.995605  432.955017
# 3        430.558533  1870.586792   422.695221  1896.009155  431.532043
# 4        429.011780  1867.699951   422.027954  1894.613647  431.073181
# ...             ...          ...          ...          ...         ...
# 531730   854.230042  1632.297729   868.068420  1535.429321  881.906738
# 531731   846.846924  1640.661621   860.170166  1542.957886  873.493408
# 531732   839.675476  1651.081787   857.386536  1553.671021  866.242065
# 531733   836.877991  1658.847534   850.040283  1566.711426  858.815125
# 531734   825.823181  1672.681641   839.521851  1576.791138  853.220520
#
#             RHeel_x     RHeel_y  gender  level  label
# 0       1905.767822  433.114258       0      3   Jump
# 1       1903.593750  432.438110       0      3   Jump
# 2       1902.013794  431.365784       0      3   Jump
# 3       1900.942139  428.800903       0      3   Jump
# 4       1906.373169  428.228760       0      3   Jump
# ...             ...         ...     ...    ...    ...
# 531730  1595.395508  886.519531       0      2   Step
# 531731  1605.133057  877.934509       0      2   Step
# 531732  1620.087402  870.669800       0      2   Step
# 531733  1632.522949  863.202576       0      2   Step
# 531734  1640.718140  857.786743       0      2   Step
#
# [531735 rows x 56 columns]

# %%
columns = list(data.columns)
print(columns)
# Out:
# ['image_filename', 'Nose_x', 'Nose_y', 'LEye_x', 'LEye_y', 'REye_x', 'REye_y', 'LEar_x', 'LEar_y', 'REar_x', 'REar_y', 'LShoulder_x', 'LShoulder_y', 'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y', 'RElbow_x', 'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y', 'LHip_x', 'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x', 'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x', 'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x', 'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y', 'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x', 'RHeel_y', 'gender', 'level', 'label']

# %% [markdown]
# ### change csv

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(data['label'])

data["label"] = encoder.transform(data["label"])
data
# 0 = jump, 1 = spin, 2 = step
# Out:
#        image_filename       Nose_x      Nose_y       LEye_x      LEye_y  \
# 0              65.jpg  1903.450439  324.195709  1896.498169  317.243469
# 1              66.jpg  1902.256348  330.161255  1902.256348  325.993469
# 2              67.jpg  1899.319946  328.725464  1917.416260  300.575562
# 3              68.jpg  1914.982666  298.280396  1916.995972  296.267059
# 4              69.jpg  1914.923340  295.087738  1910.812134  295.087738
# ...               ...          ...         ...          ...         ...
# 531735        161.jpg  1621.043457  468.746826  1584.274292  459.554535
# 531736        162.jpg  1589.072144  463.104401  1593.388794  458.787689
# 531737        163.jpg  1597.039551  459.251648  1597.039551  455.061646
# 531738        164.jpg  1597.970093  455.625610  1602.100830  451.494934
# 531739        165.jpg  1599.962891  449.902710  1604.077637  441.673309
#
#              REye_x      REye_y       LEar_x      LEar_y       REar_x  ...  \
# 0       1896.498169  317.243469  1908.085205  326.513123  1908.085205  ...
# 1       1908.508057  332.245117  1906.424072  328.077362  1916.843506  ...
# 2       1917.416260  298.564880  1901.330566  328.725464  1920.000000  ...
# 3       1914.982666  296.267059  1916.995972  296.267059  1920.000000  ...
# 4       1912.867676  295.087738  1914.923340  293.032135  1920.000000  ...
# ...             ...         ...          ...         ...          ...  ...
# 531735  1630.235840  459.554535  1584.274292  464.150665  1630.235840  ...
# 531736  1636.555664  458.787689  1593.388794  458.787689  1640.872437  ...
# 531737  1643.129761  455.061646  1597.039551  455.061646  1643.129761  ...
# 531738  1647.538574  451.494934  1602.100830  451.494934  1651.669312  ...
# 531739  1649.339233  445.788025  1604.077637  445.788025  1653.453979  ...
#
#         LSmallToe_y  RSmallToe_x  RSmallToe_y      LHeel_x     LHeel_y  \
# 0        433.114258  1877.958862   426.162018  1903.450439  435.431671
# 1        431.238159  1873.883179   425.009338  1902.474854  432.223877
# 2        430.018127  1871.919434   423.960632  1898.995605  432.955017
# 3        430.558533  1870.586792   422.695221  1896.009155  431.532043
# 4        429.011780  1867.699951   422.027954  1894.613647  431.073181
# ...             ...          ...          ...          ...         ...
# 531735   818.054504  1676.197266   827.246765  1584.274292  841.035217
# 531736   812.756165  1688.355957   817.072876  1593.388794  830.022888
# 531737   802.832886  1693.409912   807.022888  1605.419556  823.782959
# 531738   794.343567  1697.107056   794.343567  1614.492920  810.866394
# 531739   787.307922  1698.715698   783.193237  1620.536377  803.766724
#
#             RHeel_x     RHeel_y  gender  level  label
# 0       1905.767822  433.114258       0      3      0
# 1       1903.593750  432.438110       0      3      0
# 2       1902.013794  431.365784       0      3      0
# 3       1900.942139  428.800903       0      3      0
# 4       1906.373169  428.228760       0      3      0
# ...             ...         ...     ...    ...    ...
# 531735  1653.216553  845.631409       0      2      2
# 531736  1662.455811  838.656311       0      2      2
# 531737  1672.459839  827.972961       0      2      2
# 531738  1676.453491  814.997131       0      2      2
# 531739  1682.256836  803.766724       0      2      2
#
# [531740 rows x 56 columns]

# %%
data = data.drop('image_filename', axis=1)
data
# Out:
#              Nose_x      Nose_y       LEye_x      LEye_y       REye_x  \
# 0       1903.450439  324.195709  1896.498169  317.243469  1896.498169
# 1       1902.256348  330.161255  1902.256348  325.993469  1908.508057
# 2       1899.319946  328.725464  1917.416260  300.575562  1917.416260
# 3       1914.982666  298.280396  1916.995972  296.267059  1914.982666
# 4       1914.923340  295.087738  1910.812134  295.087738  1912.867676
# ...             ...         ...          ...         ...          ...
# 531735  1621.043457  468.746826  1584.274292  459.554535  1630.235840
# 531736  1589.072144  463.104401  1593.388794  458.787689  1636.555664
# 531737  1597.039551  459.251648  1597.039551  455.061646  1643.129761
# 531738  1597.970093  455.625610  1602.100830  451.494934  1647.538574
# 531739  1599.962891  449.902710  1604.077637  441.673309  1649.339233
#
#             REye_y       LEar_x      LEar_y       REar_x      REar_y  ...  \
# 0       317.243469  1908.085205  326.513123  1908.085205  324.195709  ...
# 1       332.245117  1906.424072  328.077362  1916.843506  311.406311  ...
# 2       298.564880  1901.330566  328.725464  1920.000000  298.564880  ...
# 3       296.267059  1916.995972  296.267059  1920.000000  298.280396  ...
# 4       295.087738  1914.923340  293.032135  1920.000000  295.087738  ...
# ...            ...          ...         ...          ...         ...  ...
# 531735  459.554535  1584.274292  464.150665  1630.235840  459.554535  ...
# 531736  458.787689  1593.388794  458.787689  1640.872437  454.471008  ...
# 531737  455.061646  1597.039551  455.061646  1643.129761  450.871613  ...
# 531738  451.494934  1602.100830  451.494934  1651.669312  447.364197  ...
# 531739  445.788025  1604.077637  445.788025  1653.453979  441.673309  ...
#
#         LSmallToe_y  RSmallToe_x  RSmallToe_y      LHeel_x     LHeel_y  \
# 0        433.114258  1877.958862   426.162018  1903.450439  435.431671
# 1        431.238159  1873.883179   425.009338  1902.474854  432.223877
# 2        430.018127  1871.919434   423.960632  1898.995605  432.955017
# 3        430.558533  1870.586792   422.695221  1896.009155  431.532043
# 4        429.011780  1867.699951   422.027954  1894.613647  431.073181
# ...             ...          ...          ...          ...         ...
# 531735   818.054504  1676.197266   827.246765  1584.274292  841.035217
# 531736   812.756165  1688.355957   817.072876  1593.388794  830.022888
# 531737   802.832886  1693.409912   807.022888  1605.419556  823.782959
# 531738   794.343567  1697.107056   794.343567  1614.492920  810.866394
# 531739   787.307922  1698.715698   783.193237  1620.536377  803.766724
#
#             RHeel_x     RHeel_y  gender  level  label
# 0       1905.767822  433.114258       0      3      0
# 1       1903.593750  432.438110       0      3      0
# 2       1902.013794  431.365784       0      3      0
# 3       1900.942139  428.800903       0      3      0
# 4       1906.373169  428.228760       0      3      0
# ...             ...         ...     ...    ...    ...
# 531735  1653.216553  845.631409       0      2      2
# 531736  1662.455811  838.656311       0      2      2
# 531737  1672.459839  827.972961       0      2      2
# 531738  1676.453491  814.997131       0      2      2
# 531739  1682.256836  803.766724       0      2      2
#
# [531740 rows x 55 columns]

# %% [markdown]
# ### data visualize

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='label')
plt.title('Distribution of Actions')
plt.xlabel('Action Type (0:jump, 1:spin, 2:step)')
plt.ylabel('Count')
plt.show()

print(data.value_counts('label'))
# Out:
# label
# 0    221079
# 1    180519
# 2    130142
# Name: count, dtype: int64

# %%
# !pip install tableone
# Out:
# Requirement already satisfied: tableone in c:\users\okpl8\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: jinja2>=3.1.4 in c:\users\okpl8\anaconda3\lib\site-packages (from tableone) (3.1.4)
# Requirement already satisfied: numpy>=1.19.1 in c:\users\okpl8\anaconda3\lib\site-packages (from tableone) (1.26.4)
# Requirement already satisfied: openpyxl>=3.1.2 in c:\users\okpl8\anaconda3\lib\site-packages (from tableone) (3.1.5)
# Requirement already satisfied: pandas>=2.0.3 in c:\users\okpl8\anaconda3\lib\site-packages (from tableone) (2.2.2)
# Requirement already satisfied: scipy>=1.10.1 in c:\users\okpl8\anaconda3\lib\site-packages (from tableone) (1.13.1)
# Requirement already satisfied: statsmodels>=0.14.1 in c:\users\okpl8\anaconda3\lib\site-packages (from tableone) (0.14.2)
# Requirement already satisfied: tabulate>=0.9.0 in c:\users\okpl8\anaconda3\lib\site-packages (from tableone) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\okpl8\anaconda3\lib\site-packages (from jinja2>=3.1.4->tableone) (2.1.3)
# Requirement already satisfied: et-xmlfile in c:\users\okpl8\anaconda3\lib\site-packages (from openpyxl>=3.1.2->tableone) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\okpl8\anaconda3\lib\site-packages (from pandas>=2.0.3->tableone) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\okpl8\anaconda3\lib\site-packages (from pandas>=2.0.3->tableone) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\okpl8\anaconda3\lib\site-packages (from pandas>=2.0.3->tableone) (2023.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\okpl8\anaconda3\lib\site-packages (from statsmodels>=0.14.1->tableone) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\okpl8\anaconda3\lib\site-packages (from statsmodels>=0.14.1->tableone) (24.1)
# Requirement already satisfied: six in c:\users\okpl8\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.14.1->tableone) (1.16.0)

# %%
from tableone import TableOne

continuous_vars = [col for col in data.columns if col != 'label']
categorical_vars = []

data['label'] = data['label'] = data['label'].map({0: 'Jump', 1: 'Spin', 2: 'Step'})

# TableOne 생성
mytable = TableOne(data, 
                  columns=continuous_vars, 
                  categorical=categorical_vars, 
                  groupby='label',
                  decimals=3)

# 결과 출력
print(mytable.tabulate(tablefmt="github"))
# Out:
# |                        |    | Missing   | Overall            | Jump               | Spin               | Step               |
# |------------------------|----|-----------|--------------------|--------------------|--------------------|--------------------|
# | n                      |    |           | 531740             | 221079             | 180519             | 130142             |
# | Nose_x, mean (SD)      |    | 0         | 1164.779 (302.858) | 1264.652 (291.363) | 1075.518 (221.070) | 1118.932 (364.237) |
# | Nose_y, mean (SD)      |    | 0         | 392.031 (99.682)   | 375.161 (113.194)  | 408.330 (82.904)   | 398.083 (91.710)   |
# | LEye_x, mean (SD)      |    | 0         | 1165.143 (303.540) | 1265.444 (292.220) | 1074.505 (221.740) | 1120.479 (364.301) |
# | LEye_y, mean (SD)      |    | 0         | 385.611 (98.395)   | 368.980 (111.713)  | 401.746 (82.137)   | 391.485 (90.187)   |
# | REye_x, mean (SD)      |    | 0         | 1164.970 (304.075) | 1265.045 (291.649) | 1075.456 (222.031) | 1119.130 (366.989) |
# | REye_y, mean (SD)      |    | 0         | 385.828 (98.841)   | 369.083 (111.961)  | 402.109 (82.425)   | 391.691 (91.216)   |
# | LEar_x, mean (SD)      |    | 0         | 1165.374 (306.907) | 1266.082 (294.345) | 1071.801 (225.114) | 1124.091 (369.194) |
# | LEar_y, mean (SD)      |    | 0         | 387.847 (98.502)   | 371.393 (112.209)  | 403.803 (81.777)   | 393.669 (90.176)   |
# | REar_x, mean (SD)      |    | 0         | 1171.347 (308.774) | 1271.294 (293.456) | 1078.299 (226.931) | 1130.629 (375.756) |
# | REar_y, mean (SD)      |    | 0         | 388.082 (99.190)   | 371.513 (112.694)  | 404.057 (82.271)   | 394.070 (91.546)   |
# | LShoulder_x, mean (SD) |    | 0         | 1164.871 (303.759) | 1264.715 (292.766) | 1071.093 (222.741) | 1125.341 (363.155) |
# | LShoulder_y, mean (SD) |    | 0         | 423.146 (102.894)  | 406.356 (119.474)  | 438.090 (82.408)   | 430.940 (93.489)   |
# | RShoulder_x, mean (SD) |    | 0         | 1171.127 (308.484) | 1268.535 (292.070) | 1079.596 (228.690) | 1132.619 (377.018) |
# | RShoulder_y, mean (SD) |    | 0         | 422.467 (104.719)  | 405.141 (119.610)  | 438.863 (83.606)   | 429.158 (99.396)   |
# | LElbow_x, mean (SD)    |    | 0         | 1161.333 (300.982) | 1258.891 (293.298) | 1070.009 (221.105) | 1122.282 (356.277) |
# | LElbow_y, mean (SD)    |    | 0         | 462.924 (112.167)  | 445.499 (130.050)  | 474.557 (88.559)   | 476.390 (104.457)  |
# | RElbow_x, mean (SD)    |    | 0         | 1170.650 (306.176) | 1266.350 (287.363) | 1081.782 (229.248) | 1131.349 (376.550) |
# | RElbow_y, mean (SD)    |    | 0         | 460.520 (114.795)  | 442.180 (129.084)  | 475.823 (89.818)   | 470.450 (115.555)  |
# | LWrist_x, mean (SD)    |    | 0         | 1158.612 (299.232) | 1253.589 (295.385) | 1070.808 (221.838) | 1119.062 (348.972) |
# | LWrist_y, mean (SD)    |    | 0         | 488.740 (122.838)  | 473.047 (141.492)  | 492.852 (99.124)   | 509.695 (114.600)  |
# | RWrist_x, mean (SD)    |    | 0         | 1168.335 (303.036) | 1262.939 (281.749) | 1082.733 (229.863) | 1126.364 (374.083) |
# | RWrist_y, mean (SD)    |    | 0         | 484.609 (125.962)  | 467.839 (139.266)  | 494.157 (100.198)  | 499.854 (130.837)  |
# | LHip_x, mean (SD)      |    | 0         | 1164.436 (298.919) | 1257.828 (289.200) | 1074.193 (219.601) | 1130.963 (358.997) |
# | LHip_y, mean (SD)      |    | 0         | 513.398 (118.854)  | 494.854 (140.483)  | 528.676 (89.006)   | 523.706 (110.404)  |
# | RHip_x, mean (SD)      |    | 0         | 1167.910 (301.202) | 1260.055 (288.096) | 1079.081 (222.485) | 1134.593 (366.803) |
# | RHip_y, mean (SD)      |    | 0         | 513.449 (119.607)  | 495.058 (140.687)  | 529.047 (89.800)   | 523.056 (112.424)  |
# | LKnee_x, mean (SD)     |    | 0         | 1158.472 (294.168) | 1249.843 (286.994) | 1071.828 (215.388) | 1123.438 (351.393) |
# | LKnee_y, mean (SD)     |    | 0         | 571.226 (127.501)  | 552.030 (153.635)  | 585.160 (91.333)   | 584.508 (116.974)  |
# | RKnee_x, mean (SD)     |    | 0         | 1167.085 (296.731) | 1255.240 (286.254) | 1082.182 (218.674) | 1135.099 (360.564) |
# | RKnee_y, mean (SD)     |    | 0         | 570.541 (128.629)  | 552.018 (151.861)  | 583.996 (94.162)   | 583.343 (123.003)  |
# | LAnkle_x, mean (SD)    |    | 0         | 1157.258 (293.502) | 1245.099 (287.287) | 1072.360 (216.919) | 1125.800 (349.860) |
# | LAnkle_y, mean (SD)    |    | 0         | 630.936 (136.903)  | 610.404 (165.831)  | 644.005 (97.893)   | 647.688 (123.846)  |
# | RAnkle_x, mean (SD)    |    | 0         | 1166.974 (296.499) | 1251.520 (286.723) | 1082.764 (220.228) | 1140.158 (359.954) |
# | RAnkle_y, mean (SD)    |    | 0         | 628.031 (139.892)  | 609.163 (163.573)  | 640.719 (102.763)  | 642.483 (137.195)  |
# | Head_x, mean (SD)      |    | 0         | 1167.333 (307.899) | 1268.371 (294.419) | 1074.572 (225.992) | 1124.364 (371.656) |
# | Head_y, mean (SD)      |    | 0         | 361.669 (93.692)   | 346.036 (105.850)  | 377.420 (79.073)   | 366.376 (85.900)   |
# | Neck_x, mean (SD)      |    | 0         | 1168.374 (306.432) | 1267.826 (292.716) | 1075.455 (225.184) | 1128.318 (370.665) |
# | Neck_y, mean (SD)      |    | 0         | 405.963 (101.103)  | 389.205 (115.800)  | 421.857 (82.349)   | 412.384 (93.329)   |
# | Hip_x, mean (SD)       |    | 0         | 1166.182 (300.201) | 1259.182 (288.648) | 1076.459 (221.071) | 1132.651 (363.195) |
# | Hip_y, mean (SD)       |    | 0         | 510.079 (118.483)  | 491.683 (139.559)  | 525.351 (89.186)   | 520.145 (110.631)  |
# | LBigToe_x, mean (SD)   |    | 0         | 1151.096 (290.780) | 1237.238 (287.157) | 1070.572 (213.383) | 1116.458 (345.599) |
# | LBigToe_y, mean (SD)   |    | 0         | 644.627 (138.775)  | 624.773 (168.856)  | 657.874 (97.743)   | 659.979 (125.901)  |
# | RBigToe_x, mean (SD)   |    | 0         | 1164.884 (293.398) | 1247.301 (284.769) | 1084.811 (217.836) | 1135.947 (356.192) |
# | RBigToe_y, mean (SD)   |    | 0         | 640.869 (140.911)  | 623.026 (165.495)  | 653.038 (103.097)  | 654.300 (137.594)  |
# | LSmallToe_x, mean (SD) |    | 0         | 1152.116 (290.981) | 1238.689 (287.710) | 1070.704 (213.883) | 1117.979 (344.655) |
# | LSmallToe_y, mean (SD) |    | 0         | 645.181 (138.326)  | 625.163 (168.595)  | 657.992 (98.045)   | 661.416 (124.047)  |
# | RSmallToe_x, mean (SD) |    | 0         | 1165.007 (294.610) | 1247.381 (285.157) | 1084.516 (219.001) | 1136.723 (358.691) |
# | RSmallToe_y, mean (SD) |    | 0         | 640.544 (141.855)  | 622.280 (165.965)  | 653.414 (103.879)  | 653.715 (139.604)  |
# | LHeel_x, mean (SD)     |    | 0         | 1158.145 (294.376) | 1245.709 (287.536) | 1072.533 (218.690) | 1128.147 (350.987) |
# | LHeel_y, mean (SD)     |    | 0         | 640.760 (138.363)  | 619.760 (167.467)  | 653.683 (99.549)   | 658.506 (124.651)  |
# | RHeel_x, mean (SD)     |    | 0         | 1168.063 (297.611) | 1252.622 (287.764) | 1082.870 (221.669) | 1142.587 (360.835) |
# | RHeel_y, mean (SD)     |    | 0         | 637.049 (141.515)  | 618.067 (165.215)  | 649.443 (104.370)  | 652.101 (138.906)  |
# | gender, mean (SD)      |    | 0         | 0.204 (0.403)      | 0.191 (0.393)      | 0.205 (0.403)      | 0.225 (0.418)      |
# | level, mean (SD)       |    | 0         | 2.154 (0.795)      | 2.072 (0.809)      | 2.203 (0.782)      | 2.227 (0.777)      |

# %% [markdown]
# ### 그룹간 차이 분석

# %%
import scipy.stats as stats
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Scientific notation setting
pd.set_option('display.float_format', lambda x: '%.2e' % x if abs(x) < 0.01 else '%.4f' % x)

features = [col for col in data.columns if col != 'label']
analysis_results = []

for feature in features:
    jump_data = data[data['label'] == 'Jump'][feature]
    spin_data = data[data['label'] == 'Spin'][feature]
    step_data = data[data['label'] == 'Step'][feature]
    
    f_stat, p_val = f_oneway(jump_data, spin_data, step_data)
    
    groups = [jump_data, spin_data, step_data]
    ss_between = sum(len(group) * ((group.mean() - data[feature].mean())**2) for group in groups)
    ss_total = sum((data[feature] - data[feature].mean())**2)
    eta_squared = ss_between / ss_total
    
    if eta_squared < 0.01:
        effect_size_interpretation = "Small Effect"
    elif eta_squared < 0.06:
        effect_size_interpretation = "Medium Effect"
    else:
        effect_size_interpretation = "Large Effect"
    
    desc_stats = data.groupby('label')[feature].agg(['mean', 'std']).round(4)
    
    analysis_results.append({
        'Feature': feature,
        'F-statistic': f_stat,
        'p-value': p_val,
        'Effect Size (η²)': eta_squared,
        'Effect Interpretation': effect_size_interpretation,
        'Jump_mean': desc_stats.loc['Jump', 'mean'],
        'Jump_std': desc_stats.loc['Jump', 'std'],
        'Spin_mean': desc_stats.loc['Spin', 'mean'],
        'Spin_std': desc_stats.loc['Spin', 'std'],
        'Step_mean': desc_stats.loc['Step', 'mean'],
        'Step_std': desc_stats.loc['Step', 'std']
    })

results_df = pd.DataFrame(analysis_results)
results_df = results_df.sort_values('Effect Size (η²)', ascending=False)

print("\n=== Overall Variable Analysis Results ===")
print(results_df)
# Out:
# === Overall Variable Analysis Results ===
#         Feature  F-statistic   p-value  Effect Size (η²)  \
# 10  LShoulder_x   23566.0714  0.00e+00            0.0814
# 2        LEye_x   23422.8047  0.00e+00            0.0810
# 6        LEar_x   23356.0483  0.00e+00            0.0808
# 34       Head_x   23229.5133  0.00e+00            0.0804
# 0        Nose_x   23217.0309  0.00e+00            0.0803
# 4        REye_x   23124.1330  0.00e+00            0.0800
# 36       Neck_x   22864.8940  0.00e+00            0.0792
# 14     LElbow_x   22822.7021  0.00e+00            0.0791
# 8        REar_x   22694.4239  0.00e+00            0.0786
# 18     LWrist_x   21678.9677  0.00e+00            0.0754
# 12  RShoulder_x   21605.5018  0.00e+00            0.0752
# 22       LHip_x   21431.1039  0.00e+00            0.0746
# 38        Hip_x   21023.7048  0.00e+00            0.0733
# 16     RElbow_x   21014.9002  0.00e+00            0.0733
# 26      LKnee_x   20947.5919  0.00e+00            0.0730
# 20     RWrist_x   20721.9926  0.00e+00            0.0723
# 24       RHip_x   20452.9546  0.00e+00            0.0714
# 30     LAnkle_x   19538.2931  0.00e+00            0.0685
# 48      LHeel_x   19411.1457  0.00e+00            0.0680
# 28      RKnee_x   19194.4604  0.00e+00            0.0673
# 44  LSmallToe_x   19015.0286  0.00e+00            0.0667
# 40    LBigToe_x   18785.7085  0.00e+00            0.0660
# 32     RAnkle_x   17934.2306  0.00e+00            0.0632
# 50      RHeel_x   17929.1734  0.00e+00            0.0632
# 42    RBigToe_x   17112.9966  0.00e+00            0.0605
# 46  RSmallToe_x   17000.5544  0.00e+00            0.0601
# 5        REye_y    5982.0458  0.00e+00            0.0220
# 1        Nose_y    5949.1087  0.00e+00            0.0219
# 3        LEye_y    5947.2857  0.00e+00            0.0219
# 35       Head_y    5921.5370  0.00e+00            0.0218
# 7        LEar_y    5804.1496  0.00e+00            0.0214
# 9        REar_y    5786.1591  0.00e+00            0.0213
# 37       Neck_y    5647.2831  0.00e+00            0.0208
# 13  RShoulder_y    5620.5853  0.00e+00            0.0207
# 11  LShoulder_y    5325.2825  0.00e+00            0.0196
# 17     RElbow_y    5004.8290  0.00e+00            0.0185
# 23       LHip_y    4755.3563  0.00e+00            0.0176
# 39        Hip_y    4716.0414  0.00e+00            0.0174
# 15     LElbow_y    4656.5598  0.00e+00            0.0172
# 25       RHip_y    4648.0845  0.00e+00            0.0172
# 49      LHeel_y    4478.2889  0.00e+00            0.0166
# 27      LKnee_y    4360.0218  0.00e+00            0.0161
# 31     LAnkle_y    4353.3658  0.00e+00            0.0161
# 45  LSmallToe_y    4046.2950  0.00e+00            0.0150
# 29      RKnee_y    3983.3153  0.00e+00            0.0148
# 41    LBigToe_y    3938.7482  0.00e+00            0.0146
# 19     LWrist_y    3853.9752  0.00e+00            0.0143
# 33     RAnkle_y    3493.0763  0.00e+00            0.0130
# 21     RWrist_y    3476.0215  0.00e+00            0.0129
# 51      RHeel_y    3461.7900  0.00e+00            0.0129
# 47  RSmallToe_y    3173.8017  0.00e+00            0.0118
# 43    RBigToe_y    3071.8623  0.00e+00            0.0114
# 53        level    2086.1971  0.00e+00          7.79e-03
# 52       gender     291.3524 3.44e-127          1.09e-03
#
#    Effect Interpretation  Jump_mean  Jump_std  Spin_mean  Spin_std  Step_mean  \
# 10          Large Effect  1264.7147  292.7665  1071.0932  222.7413  1125.3407
# 2           Large Effect  1265.4444  292.2204  1074.5054  221.7397  1120.4788
# 6           Large Effect  1266.0815  294.3454  1071.8009  225.1143  1124.0905
# 34          Large Effect  1268.3707  294.4194  1074.5716  225.9919  1124.3638
# 0           Large Effect  1264.6522  291.3632  1075.5178  221.0701  1118.9317
# 4           Large Effect  1265.0453  291.6488  1075.4563  222.0306  1119.1305
# 36          Large Effect  1267.8259  292.7157  1075.4549  225.1843  1128.3182
# 14          Large Effect  1258.8912  293.2976  1070.0090  221.1054  1122.2823
# 8           Large Effect  1271.2938  293.4561  1078.2994  226.9313  1130.6290
# 18          Large Effect  1253.5890  295.3853  1070.8079  221.8385  1119.0616
# 12          Large Effect  1268.5348  292.0701  1079.5958  228.6901  1132.6185
# 22          Large Effect  1257.8278  289.2003  1074.1934  219.6007  1130.9627
# 38          Large Effect  1259.1821  288.6484  1076.4586  221.0706  1132.6513
# 16          Large Effect  1266.3502  287.3628  1081.7821  229.2480  1131.3487
# 26          Large Effect  1249.8426  286.9940  1071.8279  215.3875  1123.4384
# 20          Large Effect  1262.9387  281.7493  1082.7326  229.8632  1126.3643
# 24          Large Effect  1260.0552  288.0959  1079.0806  222.4852  1134.5931
# 30          Large Effect  1245.0987  287.2870  1072.3600  216.9188  1125.7996
# 48          Large Effect  1245.7095  287.5356  1072.5335  218.6896  1128.1469
# 28          Large Effect  1255.2404  286.2540  1082.1817  218.6735  1135.0985
# 44          Large Effect  1238.6887  287.7096  1070.7038  213.8826  1117.9787
# 40          Large Effect  1237.2376  287.1569  1070.5717  213.3827  1116.4583
# 32          Large Effect  1251.5201  286.7230  1082.7636  220.2275  1140.1578
# 50          Large Effect  1252.6219  287.7644  1082.8698  221.6690  1142.5873
# 42          Large Effect  1247.3013  284.7694  1084.8111  217.8364  1135.9470
# 46          Large Effect  1247.3808  285.1570  1084.5158  219.0012  1136.7230
# 5          Medium Effect   369.0831  111.9614   402.1088   82.4250   391.6911
# 1          Medium Effect   375.1611  113.1941   408.3298   82.9045   398.0826
# 3          Medium Effect   368.9795  111.7129   401.7460   82.1366   391.4848
# 35         Medium Effect   346.0362  105.8502   377.4196   79.0727   366.3764
# 7          Medium Effect   371.3927  112.2086   403.8027   81.7765   393.6688
# 9          Medium Effect   371.5125  112.6940   404.0569   82.2711   394.0704
# 37         Medium Effect   389.2052  115.7998   421.8566   82.3493   412.3840
# 13         Medium Effect   405.1411  119.6098   438.8630   83.6058   429.1580
# 11         Medium Effect   406.3559  119.4744   438.0903   82.4081   430.9401
# 17         Medium Effect   442.1795  129.0837   475.8226   89.8177   470.4502
# 23         Medium Effect   494.8542  140.4833   528.6763   89.0062   523.7064
# 39         Medium Effect   491.6833  139.5590   525.3509   89.1864   520.1449
# 15         Medium Effect   445.4987  130.0498   474.5569   88.5590   476.3896
# 25         Medium Effect   495.0577  140.6866   529.0465   89.7995   523.0558
# 49         Medium Effect   619.7601  167.4669   653.6832   99.5489   658.5064
# 27         Medium Effect   552.0299  153.6347   585.1596   91.3326   584.5081
# 31         Medium Effect   610.4036  165.8309   644.0051   97.8930   647.6882
# 45         Medium Effect   625.1626  168.5949   657.9915   98.0447   661.4164
# 29         Medium Effect   552.0176  151.8609   583.9960   94.1625   583.3434
# 41         Medium Effect   624.7732  168.8559   657.8741   97.7435   659.9789
# 19         Medium Effect   473.0468  141.4920   492.8515   99.1244   509.6949
# 33         Medium Effect   609.1628  163.5734   640.7185  102.7628   642.4828
# 21         Medium Effect   467.8385  139.2657   494.1566  100.1983   499.8543
# 51         Medium Effect   618.0671  165.2146   649.4432  104.3704   652.1008
# 47         Medium Effect   622.2802  165.9655   653.4142  103.8794   653.7155
# 43         Medium Effect   623.0257  165.4950   653.0380  103.0966   654.3000
# 53          Small Effect     2.0717    0.8088     2.2028    0.7825     2.2269
# 52          Small Effect     0.1914    0.3934     0.2047    0.4035     0.2254
#
#     Step_std
# 10  363.1554
# 2   364.3009
# 6   369.1941
# 34  371.6556
# 0   364.2367
# 4   366.9886
# 36  370.6653
# 14  356.2774
# 8   375.7557
# 18  348.9722
# 12  377.0176
# 22  358.9971
# 38  363.1945
# 16  376.5497
# 26  351.3935
# 20  374.0831
# 24  366.8031
# 30  349.8604
# 48  350.9871
# 28  360.5639
# 44  344.6546
# 40  345.5987
# 32  359.9539
# 50  360.8351
# 42  356.1919
# 46  358.6915
# 5    91.2157
# 1    91.7097
# 3    90.1873
# 35   85.9001
# 7    90.1760
# 9    91.5461
# 37   93.3286
# 13   99.3957
# 11   93.4891
# 17  115.5549
# 23  110.4038
# 39  110.6306
# 15  104.4571
# 25  112.4238
# 49  124.6512
# 27  116.9743
# 31  123.8456
# 45  124.0468
# 29  123.0035
# 41  125.9007
# 19  114.5999
# 33  137.1951
# 21  130.8373
# 51  138.9057
# 47  139.6040
# 43  137.5936
# 53    0.7775
# 52    0.4178

# %% [markdown]
# ### 전체 effect 분포
#
# - 54개 변수 중 52개가 중간 이상의 효과 -> 대부분이 동작 구분에 유의미
# - 상위 변수는 x축 움직임(좌우)
# - 상체 변수들이 많으므로, 상체 부위가 주요하고 동작마다 상체의 자세가 다름.
# - p-value가 0에 가까움으로 실제차이로 볼수있음
# - gender는 동작 구분에서 관련이 적음

# %%
# 동작별 상위 10개의 박스플롯

top_10_features = results_df.head(10)['Feature'].tolist()

plt.figure(figsize=(15, 20))
for idx, feature in enumerate(top_10_features, 1):
    plt.subplot(5, 2, idx)
    sns.boxplot(x='label', y=feature, data=data)
    result_row = results_df[results_df['Feature']==feature].iloc[0]
    plt.title(f'{feature}\nη² = {result_row["Effect Size (η²)"]:.4f}\n{result_row["Effect Interpretation"]}')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
plt.hist(results_df['Effect Size (η²)'], bins=30)
plt.axvline(x=0.01, color='r', linestyle='--', label='Small Effect Threshold')
plt.axvline(x=0.06, color='g', linestyle='--', label='Medium Effect Threshold')
plt.axvline(x=0.14, color='b', linestyle='--', label='Large Effect Threshold')
plt.title('Distribution of Effect Sizes (η²)')
plt.xlabel('Effect Size (η²)')
plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# ### insight
# - 상위 특성들이 동작별로 뚜렷한 차이, jump가 높은 x spin이 가장 낮음, 동작내에 여러 변동성
# - η² = SS(between) / SS(total)
#    = 그룹간 제곱합 / 전체 제곱합
#    전체 변동(variation) 중에서 그룹 차이로 설명되는 비율
# 쉽게 말해 "이 변수가 그룹을 얼마나 잘 구분하는지"를 0~1 사이의 값으로 나타냄
# 의미: 왼쪽 어깨의 x좌표 변동의 8.14%가
#      Jump/Spin/Step 동작의 차이로 설명됨
#      η² < 0.01: 작은 효과 (1% 미만 설명)
# η² ≥ 0.01: 중간 효과 (1% 이상 설명)
# η² ≥ 0.06: 큰 효과 (6% 이상 설명)

# %%
effect_size_summary = results_df['Effect Interpretation'].value_counts()
print("\n=== Effect Size Classification Summary ===")
print(effect_size_summary)

print("\n=== Top 20 Variables by Effect Size ===")
top_20 = results_df[['Feature', 'Effect Size (η²)', 'p-value', 'Effect Interpretation']].head(20)
print(top_20)

results_df['max_mean_diff'] = results_df.apply(lambda row: max([
    abs(row['Jump_mean'] - row['Spin_mean']),
    abs(row['Jump_mean'] - row['Step_mean']),
    abs(row['Spin_mean'] - row['Step_mean'])
]), axis=1)

print("\n=== Top 20 Variables by Mean Difference Between Groups ===")
mean_diff_top20 = results_df.sort_values('max_mean_diff', ascending=False)[
    ['Feature', 'max_mean_diff', 'Effect Size (η²)', 'Effect Interpretation', 'p-value']
].head(20)
print(mean_diff_top20)

results_df.to_csv('group_difference_analysis_results.csv', index=False)
# Out:
# === Effect Size Classification Summary ===
# Effect Interpretation
# Large Effect     26
# Medium Effect    26
# Small Effect      2
# Name: count, dtype: int64
#
# === Top 20 Variables by Effect Size ===
#         Feature  Effect Size (η²)  p-value Effect Interpretation
# 10  LShoulder_x            0.0814 0.00e+00          Large Effect
# 2        LEye_x            0.0810 0.00e+00          Large Effect
# 6        LEar_x            0.0808 0.00e+00          Large Effect
# 34       Head_x            0.0804 0.00e+00          Large Effect
# 0        Nose_x            0.0803 0.00e+00          Large Effect
# 4        REye_x            0.0800 0.00e+00          Large Effect
# 36       Neck_x            0.0792 0.00e+00          Large Effect
# 14     LElbow_x            0.0791 0.00e+00          Large Effect
# 8        REar_x            0.0786 0.00e+00          Large Effect
# 18     LWrist_x            0.0754 0.00e+00          Large Effect
# 12  RShoulder_x            0.0752 0.00e+00          Large Effect
# 22       LHip_x            0.0746 0.00e+00          Large Effect
# 38        Hip_x            0.0733 0.00e+00          Large Effect
# 16     RElbow_x            0.0733 0.00e+00          Large Effect
# 26      LKnee_x            0.0730 0.00e+00          Large Effect
# 20     RWrist_x            0.0723 0.00e+00          Large Effect
# 24       RHip_x            0.0714 0.00e+00          Large Effect
# 30     LAnkle_x            0.0685 0.00e+00          Large Effect
# 48      LHeel_x            0.0680 0.00e+00          Large Effect
# 28      RKnee_x            0.0673 0.00e+00          Large Effect
#
# === Top 20 Variables by Mean Difference Between Groups ===
#         Feature  max_mean_diff  Effect Size (η²) Effect Interpretation  \
# 6        LEar_x       194.2806            0.0808          Large Effect
# 34       Head_x       193.7991            0.0804          Large Effect
# 10  LShoulder_x       193.6215            0.0814          Large Effect
# 8        REar_x       192.9944            0.0786          Large Effect
# 36       Neck_x       192.3710            0.0792          Large Effect
# 2        LEye_x       190.9390            0.0810          Large Effect
# 4        REye_x       189.5890            0.0800          Large Effect
# 0        Nose_x       189.1344            0.0803          Large Effect
# 12  RShoulder_x       188.9390            0.0752          Large Effect
# 14     LElbow_x       188.8822            0.0791          Large Effect
# 16     RElbow_x       184.5681            0.0733          Large Effect
# 22       LHip_x       183.6344            0.0746          Large Effect
# 18     LWrist_x       182.7811            0.0754          Large Effect
# 38        Hip_x       182.7235            0.0733          Large Effect
# 24       RHip_x       180.9746            0.0714          Large Effect
# 20     RWrist_x       180.2061            0.0723          Large Effect
# 26      LKnee_x       178.0147            0.0730          Large Effect
# 48      LHeel_x       173.1760            0.0680          Large Effect
# 28      RKnee_x       173.0587            0.0673          Large Effect
# 30     LAnkle_x       172.7387            0.0685          Large Effect
#
#     p-value
# 6  0.00e+00
# 34 0.00e+00
# 10 0.00e+00
# 8  0.00e+00
# 36 0.00e+00
# 2  0.00e+00
# 4  0.00e+00
# 0  0.00e+00
# 12 0.00e+00
# 14 0.00e+00
# 16 0.00e+00
# 22 0.00e+00
# 18 0.00e+00
# 38 0.00e+00
# 24 0.00e+00
# 20 0.00e+00
# 26 0.00e+00
# 48 0.00e+00
# 28 0.00e+00
# 30 0.00e+00

# %% [markdown]
# ##

# %% [markdown]
# ### 결론
# - 54개 중 42개가 중간의상의 효과
# - x축이며 상체, p-value가 매우 작으므로 통계적으로 유의미
# - 상위 5개:
# 1. LEar_x: 194.28 픽셀 차이
# 2. Head_x: 193.79 픽셀 차이
# 3. LShoulder_x: 193.62 픽셀 차이
# 4. REar_x: 192.99 픽셀 차이
# 5. Neck_x: 192.37 픽셀 차이
# - 동작간 차이가 194픽셀까지 나는데 동작구분이 명확할수있음을 시사
# - 왼쪽이 오른쪽 보다 더 큰 효과를 보이며, 카메라 기준 왼쪽으로 돌아서 그럴수도
#
# 1. 상체의 좌우 움직임에 집중해야 함
# 2. 특히 왼쪽 신체 부위의 움직임이 중요
# 3. 머리, 어깨, 귀 부위의 추적이 핵심적

# %% [markdown]
# ### 추가
# x좌표 (좌우):
# - 왼쪽에서 오른쪽으로 갈수록 값이 증가
# - 예: LShoulder_x의 경우
#   Jump: 1264.71 픽셀 (더 오른쪽)
#   Spin: 1071.09 픽셀 (더 왼쪽)
#   Step: 1125.34 픽셀 (중간)
#
# y좌표 (상하):
# - 위에서 아래로 갈수록 값이 증가

# %%
data.head()
# Out:
#      Nose_x   Nose_y    LEye_x   LEye_y    REye_x   REye_y    LEar_x   LEar_y  \
# 0 1903.4504 324.1957 1896.4982 317.2435 1896.4982 317.2435 1908.0852 326.5131
# 1 1902.2563 330.1613 1902.2563 325.9935 1908.5081 332.2451 1906.4241 328.0774
# 2 1899.3199 328.7255 1917.4163 300.5756 1917.4163 298.5649 1901.3306 328.7255
# 3 1914.9827 298.2804 1916.9960 296.2671 1914.9827 296.2671 1916.9960 296.2671
# 4 1914.9233 295.0877 1910.8121 295.0877 1912.8677 295.0877 1914.9233 293.0321
#
#      REar_x   REar_y  ...  LSmallToe_y  RSmallToe_x  RSmallToe_y   LHeel_x  \
# 0 1908.0852 324.1957  ...     433.1143    1877.9589     426.1620 1903.4504
# 1 1916.8435 311.4063  ...     431.2382    1873.8832     425.0093 1902.4749
# 2 1920.0000 298.5649  ...     430.0181    1871.9194     423.9606 1898.9956
# 3 1920.0000 298.2804  ...     430.5585    1870.5868     422.6952 1896.0092
# 4 1920.0000 295.0877  ...     429.0118    1867.7000     422.0280 1894.6136
#
#    LHeel_y   RHeel_x  RHeel_y  gender  level  label
# 0 435.4317 1905.7678 433.1143       0      3   Jump
# 1 432.2239 1903.5938 432.4381       0      3   Jump
# 2 432.9550 1902.0138 431.3658       0      3   Jump
# 3 431.5320 1900.9421 428.8009       0      3   Jump
# 4 431.0732 1906.3732 428.2288       0      3   Jump
#
# [5 rows x 55 columns]

# %% [markdown]
# ## heatmap

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(data['label'])

data["label"] = encoder.transform(data["label"])
data
# 0 = jump, 1 = spin, 2 = step
# Out:
#           Nose_x   Nose_y    LEye_x   LEye_y    REye_x   REye_y    LEar_x  \
# 0      1903.4504 324.1957 1896.4982 317.2435 1896.4982 317.2435 1908.0852
# 1      1902.2563 330.1613 1902.2563 325.9935 1908.5081 332.2451 1906.4241
# 2      1899.3199 328.7255 1917.4163 300.5756 1917.4163 298.5649 1901.3306
# 3      1914.9827 298.2804 1916.9960 296.2671 1914.9827 296.2671 1916.9960
# 4      1914.9233 295.0877 1910.8121 295.0877 1912.8677 295.0877 1914.9233
# ...          ...      ...       ...      ...       ...      ...       ...
# 531735 1621.0435 468.7468 1584.2743 459.5545 1630.2358 459.5545 1584.2743
# 531736 1589.0721 463.1044 1593.3888 458.7877 1636.5557 458.7877 1593.3888
# 531737 1597.0396 459.2516 1597.0396 455.0616 1643.1298 455.0616 1597.0396
# 531738 1597.9701 455.6256 1602.1008 451.4949 1647.5386 451.4949 1602.1008
# 531739 1599.9629 449.9027 1604.0776 441.6733 1649.3392 445.7880 1604.0776
#
#          LEar_y    REar_x   REar_y  ...  LSmallToe_y  RSmallToe_x  \
# 0      326.5131 1908.0852 324.1957  ...     433.1143    1877.9589
# 1      328.0774 1916.8435 311.4063  ...     431.2382    1873.8832
# 2      328.7255 1920.0000 298.5649  ...     430.0181    1871.9194
# 3      296.2671 1920.0000 298.2804  ...     430.5585    1870.5868
# 4      293.0321 1920.0000 295.0877  ...     429.0118    1867.7000
# ...         ...       ...      ...  ...          ...          ...
# 531735 464.1507 1630.2358 459.5545  ...     818.0545    1676.1973
# 531736 458.7877 1640.8724 454.4710  ...     812.7562    1688.3560
# 531737 455.0616 1643.1298 450.8716  ...     802.8329    1693.4099
# 531738 451.4949 1651.6693 447.3642  ...     794.3436    1697.1071
# 531739 445.7880 1653.4540 441.6733  ...     787.3079    1698.7157
#
#         RSmallToe_y   LHeel_x  LHeel_y   RHeel_x  RHeel_y  gender  level  \
# 0          426.1620 1903.4504 435.4317 1905.7678 433.1143       0      3
# 1          425.0093 1902.4749 432.2239 1903.5938 432.4381       0      3
# 2          423.9606 1898.9956 432.9550 1902.0138 431.3658       0      3
# 3          422.6952 1896.0092 431.5320 1900.9421 428.8009       0      3
# 4          422.0280 1894.6136 431.0732 1906.3732 428.2288       0      3
# ...             ...       ...      ...       ...      ...     ...    ...
# 531735     827.2468 1584.2743 841.0352 1653.2166 845.6314       0      2
# 531736     817.0729 1593.3888 830.0229 1662.4558 838.6563       0      2
# 531737     807.0229 1605.4196 823.7830 1672.4598 827.9730       0      2
# 531738     794.3436 1614.4929 810.8664 1676.4535 814.9971       0      2
# 531739     783.1932 1620.5364 803.7667 1682.2568 803.7667       0      2
#
#         label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 531735      2
# 531736      2
# 531737      2
# 531738      2
# 531739      2
#
# [531740 rows x 55 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(20, 16))
correlation = data.corr()
sns.heatmap(correlation,
            cmap='coolwarm',
            center=0,
            annot=True,
            fmt='.2f')
plt.title('corr heatmap')
plt.show()

# %% [markdown]
# ### 해석
# - x좌표들간 강한 양의 상관관계
# - y좌표들간 강한 양의 상관관계
# - x,y의 관계는 약한 상관관계

# %%
# 주요 특성 히트맵
top_20_features = results_df.head(20)['Feature'].tolist()
plt.figure(figsize=(15, 12))
correlation_top20 = data[top_20_features].corr()
sns.heatmap(correlation_top20,
            cmap='coolwarm',
            center=0,
            annot=True,      # 상위 20개만 보므로 값을 표시
            fmt='.2f')
plt.title('Correlation Heatmap of Top 20 Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 상위 20개 특성 해석
# - 대부분 x좌표
# |- 강함
# - 특정 상체 부위가 매우 강함 (붙어있는 것)_

# %%
# 3. 각 동작별 평균값의 히트맵
# x, y 좌표를 구분하여 시각화
features_x = [f for f in data.columns if f.endswith('_x') and f != 'label']
features_y = [f for f in data.columns if f.endswith('_y') and f != 'label']

# X 좌표에 대한 히트맵
mean_by_label_x = data.groupby('label')[features_x].mean()
plt.figure(figsize=(15, 5))
sns.heatmap(mean_by_label_x,
            cmap='coolwarm',
            center=mean_by_label_x.mean().mean(),
            annot=True,
            fmt='.1f')
plt.title('Mean X-coordinates by Movement Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 동작별 평균 값
# - x좌표에서 jump는 높음(오른쪽에 위치), spin은 낮음(왼쪽 값), step은 중간
# - y좌표에서는 jump는 낮은 값(위), spin은 높음(아래)

# %%
# Y 좌표에 대한 히트맵
mean_by_label_y = data.groupby('label')[features_y].mean()
plt.figure(figsize=(15, 5))
sns.heatmap(mean_by_label_y,
            cmap='coolwarm',
            center=mean_by_label_y.mean().mean(),
            annot=True,
            fmt='.1f')
plt.title('Mean Y-coordinates by Movement Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### effect size
# - x보다 y가 효과가 더 적음

# %%
# 4. Effect Size 히트맵
# x, y 좌표별로 effect size를 시각화
effect_sizes = results_df[['Feature', 'Effect Size (η²)']]
effect_sizes_matrix = pd.DataFrame(index=['x', 'y'])

# 각 신체 부위별로 x, y 좌표의 effect size를 매트릭스로 변환
for feature in effect_sizes['Feature']:
    if feature not in ['level', 'gender']:
        body_part = feature.rsplit('_', 1)[0]
        coord = feature.rsplit('_', 1)[1]
        effect_size = effect_sizes[effect_sizes['Feature'] == feature]['Effect Size (η²)'].values[0]
        effect_sizes_matrix.loc[coord, body_part] = effect_size

plt.figure(figsize=(15, 5))
sns.heatmap(effect_sizes_matrix,
            cmap='YlOrRd',
            annot=True,
            fmt='.3f')
plt.title('Effect Sizes (η²) by Body Part and Coordinate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## pearson 상관관계 히트맵

# %%
# 전체 상관관계 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 16))
correlation = data.corr(method='pearson')

sns.heatmap(correlation,
            cmap='coolwarm',
            center=0,
            annot=True,
            fmt='.2f',
            square=True,
            vmin=-1,
            vmax=1)

plt.title('pearson Correlataion Map of All')
plt.show()

# %% [markdown]
# ### all
# - x,y끼리 군집
# - gender, lebel은 약함
# - 상체의 x가 강한 상관관계
# - 하체로 갈수록 약해짐

# %%
# 상위 20개 특성 corr
top_20 = results_df.head(20)['Feature'].tolist()
plt.figure(figsize=(15,12))
correlation_20 = data[top_20].corr(method='pearson')

sns.heatmap(correlation_20,
            cmap='coolwarm',
            annot=True,
            fmt='.2f',
            square=True,
            vmin=-1,
            vmax=1)
plt.title('pearson corr top 20')
plt.show()

# %% [markdown]
# ### 20
# - 대부분 x.좌표이며 높은 상관계수임 0.8, 1.0
# - 머리 어깨 팔의 위치가 같으면 높음

# %%
# 상관관계 hist
plt.figure(figsize=(12,6))
corr_value = correlation.values.flatten()
plt.hist(corr_value, bins=50)
plt.title('Distribution of Correlation Coefficients')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 상관관계 히스트
# - 매우 강한 양의 상관관계를 가진 변수가 많음
# - 음의 상관관계는 반대로 움직이는 관계를 나타냄
# - 많은 신체 부위가 같은 방향으로 움직이고, 상체부위가 많음

# %% [markdown]
# ### 모든 변수가 동일한 단위에 있으므로 스케일링은 따로 진행하지 않음
